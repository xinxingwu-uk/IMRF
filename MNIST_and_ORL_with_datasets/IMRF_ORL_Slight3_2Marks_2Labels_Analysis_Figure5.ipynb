# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

#K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical,plot_model
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit,train_test_split,StratifiedKFold
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from skimage import io
from PIL import Image
import scipy.sparse as sparse
import pandas as pd
import random
import h5py
import math
import gc
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mlxtend.plotting import plot_confusion_matrix

# %matplotlib inline
matplotlib.style.use('ggplot')

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Parameters

# %%
dataset_path='./data/faces/ORL_Faces/'

original_edge_length=92
original_edge_width=112

black_area=4

number_samples_for_show=30

minority1=30
minority2=70
minority3=40
majority=90
sampling_times=100
seed_range=np.random.randint(100,size=100)#np.arange(0,100,1)
p_n_estimators=2100

# %% [markdown]
# # 3. Import data

# %% [markdown]
# ## 3.1 Loading data

# %%
points = {}

for dirpath, dirnames, filenames in os.walk(dataset_path):
    dirnames.sort()
    filenames.sort()
    for filename in [f for f in filenames if f.endswith(".pgm") and not f[0] == '.']:
        full_path = os.path.join(dirpath, filename)
        filename = full_path.split('/')[-1]
        file_identifier="%s" % (full_path.split('/')[-3])
        #print(file_identifier)
        if file_identifier not in points.keys():
            points[file_identifier] = []
        #image = io.imread(full_path)
        image_=Image.open(full_path).resize((original_edge_length, original_edge_width),Image.ANTIALIAS)
        image=np.asarray(image_)
        points[file_identifier].append(image)

#--------------------------------------------------------------------------------------------------------------------------------
Feature = []
for key in points.keys():
    for image_i in range(len(points[key])):
        Feature.append(np.array(points[key][image_i]))

Features=np.array(Feature)
rn.shuffle(Features)

Features_part1=Features[0:(400-minority1-minority2-minority3)]
Features_part2=Features[(400-minority1-minority2-minority3):(400-minority2-minority3)]
Features_part3=Features[(400-minority2-minority3):(400-minority3)]
Features_part4=Features[(400-minority3):]

Labels=np.r_[np.array([0]*(400-minority1-minority2-minority3)),np.array([1]*minority1),np.array([2]*minority2),np.array([3]*minority3)]

# %% [markdown]
# ## 3.2 Add noise to data

# %%
#--------------------------------------------------------------------------------------------------------------------------------
Collect1_noise_data=[]
for i in np.arange(400-minority1-minority2-minority3):
    Collect1_noise_data_i=np.zeros(Features_part2[1].shape)
    Collect1_noise_data.append(Collect1_noise_data_i)

#--------------------------------------------------------------------------------------------------------------------------------
Collect2_noise_data=[]
for i in np.arange(0,minority1):
    Features_part2_i=Features_part2[i]
    
    noise_data=Features_part2_i
    
    Collect2_noise_data_i=np.zeros(Features_part2[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)

for i in np.arange(0,minority2):
    Features_part3_i=Features_part3[i]
    
    noise_data=Features_part3_i
    
    Collect2_noise_data_i=np.zeros(Features_part3[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):         
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
    
for i in np.arange(0,minority3):
    Features_part4_i=Features_part4[i]
    
    noise_data=Features_part4_i
    
    Collect2_noise_data_i=np.zeros(Features_part4[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1   
            
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
#--------------------------------------------------------------------------------------------------------------------------------
Array_Feature = []
for i in np.arange(Features.shape[0]):
    Array_Feature.append(Features[i].flatten())

#--------------------------------------------------------------------------------------------------------------------------------
Collect_noise_data=np.array(Collect1_noise_data+Collect2_noise_data)
print('Shape of Collect_noise_data',Collect_noise_data.shape)
# Out:
# Shape of Collect_noise_data (400, 112, 92)

# %%
rand_indices = np.random.permutation(400)

Array_Feature_=np.array(Array_Feature)[rand_indices]
Labels_=np.array(Labels)[rand_indices]

# %% [markdown]
# ## 3.3 The number of samples for different classes

# %%
for i in np.arange(4):
    print(i,":",np.sum(Labels_==i))
# Out:
# 0 : 260
# 1 : 30
# 2 : 70
# 3 : 40

# %%
index_used=np.r_[np.where(Labels_==1)[0],np.where(Labels_==2)[0]]

Labels_used=Labels_[index_used]
Array_Feature_used=Array_Feature_[index_used]

# %% [markdown]
# ## 3.4 Do undersampling and generate multiple sample subsets

# %%
Samples_list=[]
Labels_for_Samples_list=[]
for time_i in np.arange(sampling_times):
    seed_i=time_i
    rus=RandomOverSampler(sampling_strategy={1:70,2:70},random_state=seed_i)
    Samples_,Labels_for_Samples_=rus.fit_sample(Array_Feature_used,Labels_used)
    Samples_list.append(Samples_)
    Labels_for_Samples_list.append(Labels_for_Samples_)

# %% [markdown]
# ## 3.5 Split training and testing samples

# %%
X_train_list=[]
X_test_list=[]
y_train_list=[]
y_test_list=[]

for time_i in np.arange(sampling_times):
    Samples_list_i_=Samples_list[time_i]
    Labels_for_Samples_i_=Labels_for_Samples_list[time_i]
    rand_indices = np.random.permutation(70+70)
    Samples_list_i=Samples_list_i_[rand_indices]
    Labels_for_Samples_i=Labels_for_Samples_i_[rand_indices]
    
    X_train_i,X_test_i, y_train_i, y_test_i =train_test_split(Samples_list_i,Labels_for_Samples_i,test_size=0.3, random_state=seed)

    print('Shape of X_train_i: ' + str(X_train_i.shape))
    print('Shape of y_train_i: ' + str(y_train_i.shape))
    print('Shape of X_test_i: ' + str(X_test_i.shape))
    print('Shape of y_test_i: ' + str(y_test_i.shape))
    
    X_train_list.append(X_train_i)
    X_test_list.append(X_test_i)
    y_train_list.append(y_train_i)
    y_test_list.append(y_test_i)
    
    print("\n======================================================\n\n")
# Out:
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================

# %% [markdown]
# ## 3.6 Display training and testing samples

# %%
F.show_data_figures(np.array(X_train_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)
# Out:
# ./Defined/Functions.py:71: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(p_pad,p_w_pad, p_h_pad)

# %%
y_train_list[0][0:number_samples_for_show]
# Out:
# array([1, 2, 2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2,
#        2, 1, 2, 2, 1, 2, 1, 2])

# %%
F.show_data_figures(np.array(X_train_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2,
#        1, 1, 2, 1, 2, 1, 2, 1])

# %%
F.show_data_figures(np.array(X_test_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_test_list[0][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 2, 1, 2, 2, 2, 1, 1, 1, 2,
#        2, 2, 1, 2, 1, 1, 2, 1])

# %%
F.show_data_figures(np.array(X_test_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2,
#        1, 1, 2, 1, 2, 1, 2, 1])

# %% [markdown]
# # 4 Analysis

# %% [markdown]
# ## 4.1 Improt predicated results

# %%
path_predicated_results="./RF_results_2L/predicated_results_sl3_2M_4L.csv"
predicated_results=pd.read_csv(path_predicated_results, sep='delimiter', header=None)
class_names=["N1-Clean fact","N2-Clean fact"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %% [markdown]
# ## 4.2 Average accuarcy and confusion matrix

# %%
time_i=int(predicated_results.shape[0]/(4*len(seed_range)))
print("The number of samplings: ",time_i)

Acc_train_ave_collect=[]
Acc_test_ave_collect=[]
conf_martix_ave_collect=[]
report_matrix_ave_collect=[]

for time_i in np.arange(time_i):
    print("Sampling "+str(time_i+1)+"----------------------------------------------------------------------------------\n")
    
    Acc_train_list=[]
    Acc_test_list=[]

    conf_martix=[]
    report_matrix=[]

    for pred_i in np.arange(len(seed_range)*time_i,len(seed_range)*(time_i+1)):
    
        Acc_train=np.array(predicated_results)[4*pred_i]
        Acc_test=np.array(predicated_results)[4*pred_i+1]
        p_y_pred=np.array(predicated_results)[4*pred_i+2]
        p_y_test=np.array(predicated_results)[4*pred_i+3]
        
        Acc_train_list.append(Acc_train)
        Acc_test_list.append(Acc_test)
    
        pred_set=np.array(p_y_pred[0].split(",")).astype(float)
        truth_set=np.array(p_y_test[0].split(",")).astype(float)

        conf_martix_i = np.array(confusion_matrix(truth_set, pred_set))
        conf_martix.append(conf_martix_i)

        report = classification_report(truth_set, pred_set)
        report_matrix_i=[]
        report_matrix_i.append(np.array(report.split('\n')[2].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[3].split()[1:]).astype(float))
        report_matrix_i.append(np.array(['nan','nan']+report.split('\n')[5].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[6].split()[2:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[7].split()[2:]).astype(float))

        report_matrix.append(np.array(report_matrix_i))
    
    # Accuarcy---------------------------------------------------------------------------------------------------------
    Acc_train_ave=np.average(np.array(Acc_train_list).astype(float))
    Acc_test_ave=np.average(np.array(Acc_test_list).astype(float))
    print("Acc_train_ave: ",Acc_train_ave)
    print("Acc_test_ave: ",Acc_test_ave)
    print('\n')

    Acc_train_ave_collect.append(Acc_train_ave)
    Acc_test_ave_collect.append(Acc_test_ave)
    
    # Confusion martix---------------------------------------------------------------------------------------------------------
    conf_martix_ave=np.average(conf_martix,axis=0)
    print("Confusion martix: ",conf_martix_ave)
    print('\n')

    conf_martix_ave_collect.append(conf_martix_ave)

    # Report---------------------------------------------------------------------------------------------------------
    report_matrix_ave=np.average(report_matrix,axis=0)
    Title=np.array(['Classes']+report.split('\n')[0].split()).reshape(1,5)
    report_matrix_ave_=np.c_[np.array(class_names+['accuracy','macro avg','weighted avg']),np.round(report_matrix_ave,decimals=4).astype(str)]

    report_matrix_ave_mergetitle=np.r_[np.array(Title),report_matrix_ave_]

    for i in report_matrix_ave_mergetitle:
        print('\t\t'.join(i))
        
    report_matrix_ave_collect.append(report_matrix_ave)
    
    print("\n\n\n")
# Out:
# The number of samplings:  100
# Sampling 1----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.785714285714286
#
#
# Confusion martix:  [[17.  4.]
#  [ 5. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7704		0.81		0.79		21.0
# N2-Clean fact		0.8		0.76		0.78		21.0
# accuracy		nan		nan		0.7896		42.0
# macro avg		0.7896		0.7896		0.7896		42.0
# weighted avg		0.7896		0.7896		0.7896		42.0
#
#
#
#
# Sampling 2----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6426190476190479
#
#
# Confusion martix:  [[11.    7.  ]
#  [ 8.01 15.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5797		0.61		0.5901		18.0
# N2-Clean fact		0.6996		0.6693		0.6797		24.0
# accuracy		nan		nan		0.64		42.0
# macro avg		0.6398		0.6398		0.6398		42.0
# weighted avg		0.6498		0.64		0.64		42.0
#
#
#
#
# Sampling 3----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8380952380952381
#
#
# Confusion martix:  [[17.   1. ]
#  [ 5.8 18.2]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7466		0.94		0.834		18.0
# N2-Clean fact		0.9489		0.758		0.8435		24.0
# accuracy		nan		nan		0.8365		42.0
# macro avg		0.8451		0.854		0.8365		42.0
# weighted avg		0.8615		0.8365		0.8365		42.0
#
#
#
#
# Sampling 4----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7966666666666669
#
#
# Confusion martix:  [[21.    2.  ]
#  [ 6.54 12.46]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7638		0.91		0.8294		23.0
# N2-Clean fact		0.8643		0.6538		0.7441		19.0
# accuracy		nan		nan		0.799		42.0
# macro avg		0.8097		0.7835		0.7895		42.0
# weighted avg		0.8092		0.799		0.793		42.0
#
#
#
#
# Sampling 5----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[17.  3.]
#  [ 5. 17.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.77		0.85		0.81		20.0
# N2-Clean fact		0.85		0.77		0.81		22.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.81		0.81		42.0
# weighted avg		0.81		0.81		0.81		42.0
#
#
#
#
# Sampling 6----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7726190476190475
#
#
# Confusion martix:  [[16.    3.  ]
#  [ 6.55 16.45]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7135		0.84		0.769		19.0
# N2-Clean fact		0.8445		0.7177		0.7735		23.0
# accuracy		nan		nan		0.7738		42.0
# macro avg		0.779		0.779		0.7738		42.0
# weighted avg		0.7842		0.7738		0.7738		42.0
#
#
#
#
# Sampling 7----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[15.  5.]
#  [ 5. 17.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.75		0.75		0.75		20.0
# N2-Clean fact		0.77		0.77		0.77		22.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 8----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[21.  5.]
#  [ 5. 11.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.81		0.81		0.81		26.0
# N2-Clean fact		0.69		0.69		0.69		16.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.75		0.75		0.75		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 9----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9047619047619047
#
#
# Confusion martix:  [[22.  3.]
#  [ 1. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.96		0.88		0.92		25.0
# N2-Clean fact		0.84		0.94		0.89		17.0
# accuracy		nan		nan		0.9		42.0
# macro avg		0.9		0.91		0.9		42.0
# weighted avg		0.91		0.9		0.91		42.0
#
#
#
#
# Sampling 10----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7745238095238095
#
#
# Confusion martix:  [[11.38  8.62]
#  [ 0.85 21.15]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9303		0.569		0.704		20.0
# N2-Clean fact		0.7134		0.9575		0.8163		22.0
# accuracy		nan		nan		0.7752		42.0
# macro avg		0.8197		0.7652		0.7609		42.0
# weighted avg		0.8183		0.7752		0.7609		42.0
#
#
#
#
# Sampling 11----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.782857142857143
#
#
# Confusion martix:  [[17.    8.  ]
#  [ 1.12 15.88]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.934		0.68		0.7876		25.0
# N2-Clean fact		0.6676		0.9328		0.7764		17.0
# accuracy		nan		nan		0.7864		42.0
# macro avg		0.8052		0.8064		0.7864		42.0
# weighted avg		0.8264		0.7864		0.7864		42.0
#
#
#
#
# Sampling 12----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8371428571428571
#
#
# Confusion martix:  [[18.    2.  ]
#  [ 4.84 17.16]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7889		0.9		0.8432		20.0
# N2-Clean fact		0.8941		0.7805		0.8348		22.0
# accuracy		nan		nan		0.8373		42.0
# macro avg		0.8432		0.8407		0.8373		42.0
# weighted avg		0.8432		0.8373		0.8373		42.0
#
#
#
#
# Sampling 13----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8571428571428572
#
#
# Confusion martix:  [[24.  2.]
#  [ 4. 12.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.86		0.92		0.89		26.0
# N2-Clean fact		0.86		0.75		0.8		16.0
# accuracy		nan		nan		0.86		42.0
# macro avg		0.86		0.84		0.84		42.0
# weighted avg		0.86		0.86		0.86		42.0
#
#
#
#
# Sampling 14----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9045238095238094
#
#
# Confusion martix:  [[22.    0.  ]
#  [ 4.01 15.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8496		1.0		0.9198		22.0
# N2-Clean fact		1.0		0.7995		0.8897		20.0
# accuracy		nan		nan		0.8998		42.0
# macro avg		0.9199		0.8998		0.8998		42.0
# weighted avg		0.9198		0.8998		0.8998		42.0
#
#
#
#
# Sampling 15----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8769047619047621
#
#
# Confusion martix:  [[22.    4.  ]
#  [ 1.17 14.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9532		0.85		0.8966		26.0
# N2-Clean fact		0.7883		0.9298		0.8532		16.0
# accuracy		nan		nan		0.8766		42.0
# macro avg		0.8666		0.8849		0.8749		42.0
# weighted avg		0.8849		0.8766		0.8766		42.0
#
#
#
#
# Sampling 16----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7380952380952382
#
#
# Confusion martix:  [[14.  8.]
#  [ 3. 17.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.82		0.64		0.72		22.0
# N2-Clean fact		0.68		0.85		0.76		20.0
# accuracy		nan		nan		0.74		42.0
# macro avg		0.75		0.74		0.74		42.0
# weighted avg		0.76		0.74		0.74		42.0
#
#
#
#
# Sampling 17----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7621428571428569
#
#
# Confusion martix:  [[16.    2.  ]
#  [ 7.99 16.01]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6703		0.89		0.7602		18.0
# N2-Clean fact		0.89		0.6704		0.7603		24.0
# accuracy		nan		nan		0.7603		42.0
# macro avg		0.7802		0.7802		0.7603		42.0
# weighted avg		0.7902		0.7603		0.7603		42.0
#
#
#
#
# Sampling 18----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7385714285714287
#
#
# Confusion martix:  [[17.    2.  ]
#  [ 8.98 14.02]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6506		0.89		0.7602		19.0
# N2-Clean fact		0.88		0.6108		0.7206		23.0
# accuracy		nan		nan		0.7404		42.0
# macro avg		0.7604		0.7504		0.7404		42.0
# weighted avg		0.7704		0.7404		0.7306		42.0
#
#
#
#
# Sampling 19----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8333333333333331
#
#
# Confusion martix:  [[20.  7.]
#  [ 0. 15.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		1.0		0.74		0.85		27.0
# N2-Clean fact		0.68		1.0		0.81		15.0
# accuracy		nan		nan		0.83		42.0
# macro avg		0.84		0.87		0.83		42.0
# weighted avg		0.89		0.83		0.84		42.0
#
#
#
#
# Sampling 20----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.75
#
#
# Confusion martix:  [[14.  10. ]
#  [ 0.5 17.5]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.965		0.58		0.73		24.0
# N2-Clean fact		0.635		0.97		0.77		18.0
# accuracy		nan		nan		0.75		42.0
# macro avg		0.8		0.775		0.75		42.0
# weighted avg		0.825		0.75		0.745		42.0
#
#
#
#
# Sampling 21----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.644761904761905
#
#
# Confusion martix:  [[14.06  8.94]
#  [ 5.98 13.02]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7016		0.6127		0.6522		23.0
# N2-Clean fact		0.5922		0.6812		0.6319		19.0
# accuracy		nan		nan		0.642		42.0
# macro avg		0.6516		0.6517		0.642		42.0
# weighted avg		0.6518		0.642		0.642		42.0
#
#
#
#
# Sampling 22----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8430952380952378
#
#
# Confusion martix:  [[16.58  1.42]
#  [ 5.17 18.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7614		0.9176		0.834		18.0
# N2-Clean fact		0.9328		0.7832		0.85		24.0
# accuracy		nan		nan		0.844		42.0
# macro avg		0.8457		0.8543		0.8433		42.0
# weighted avg		0.8578		0.844		0.844		42.0
#
#
#
#
# Sampling 23----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7150000000000002
#
#
# Confusion martix:  [[17.    3.  ]
#  [ 8.97 13.03]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6548		0.85		0.7408		20.0
# N2-Clean fact		0.8103		0.5936		0.6833		22.0
# accuracy		nan		nan		0.714		42.0
# macro avg		0.7316		0.7214		0.713		42.0
# weighted avg		0.7398		0.714		0.7111		42.0
#
#
#
#
# Sampling 24----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7576190476190477
#
#
# Confusion martix:  [[16.25  6.75]
#  [ 3.43 15.57]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8253		0.71		0.7589		23.0
# N2-Clean fact		0.6989		0.8185		0.7521		19.0
# accuracy		nan		nan		0.7578		42.0
# macro avg		0.7621		0.7621		0.7578		42.0
# weighted avg		0.7707		0.7578		0.7578		42.0
#
#
#
#
# Sampling 25----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7464285714285717
#
#
# Confusion martix:  [[18.    5.  ]
#  [ 5.65 13.35]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7605		0.78		0.7735		23.0
# N2-Clean fact		0.727		0.701		0.714		19.0
# accuracy		nan		nan		0.747		42.0
# macro avg		0.747		0.7405		0.7405		42.0
# weighted avg		0.747		0.747		0.747		42.0
#
#
#
#
# Sampling 26----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7192857142857142
#
#
# Confusion martix:  [[13.    8.  ]
#  [ 3.79 17.21]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7706		0.62		0.6843		21.0
# N2-Clean fact		0.6821		0.8205		0.7463		21.0
# accuracy		nan		nan		0.7164		42.0
# macro avg		0.7263		0.7164		0.7142		42.0
# weighted avg		0.7263		0.7164		0.7142		42.0
#
#
#
#
# Sampling 27----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8807142857142858
#
#
# Confusion martix:  [[16.    3.  ]
#  [ 2.01 20.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8895		0.84		0.8598		19.0
# N2-Clean fact		0.8799		0.9096		0.8898		23.0
# accuracy		nan		nan		0.8798		42.0
# macro avg		0.8798		0.8798		0.8798		42.0
# weighted avg		0.8798		0.8798		0.8798		42.0
#
#
#
#
# Sampling 28----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.870952380952381
#
#
# Confusion martix:  [[17.    3.  ]
#  [ 2.42 19.58]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8732		0.85		0.8616		20.0
# N2-Clean fact		0.866		0.8892		0.8776		22.0
# accuracy		nan		nan		0.8714		42.0
# macro avg		0.8714		0.8714		0.8714		42.0
# weighted avg		0.8714		0.8714		0.8714		42.0
#
#
#
#
# Sampling 29----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[18.  6.]
#  [ 2. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9		0.75		0.82		24.0
# N2-Clean fact		0.73		0.89		0.8		18.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.82		0.81		42.0
# weighted avg		0.83		0.81		0.81		42.0
#
#
#
#
# Sampling 30----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8221428571428572
#
#
# Confusion martix:  [[15.96  2.04]
#  [ 5.43 18.57]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7477		0.8876		0.8102		18.0
# N2-Clean fact		0.8985		0.7728		0.8308		24.0
# accuracy		nan		nan		0.8213		42.0
# macro avg		0.8215		0.8302		0.8213		42.0
# weighted avg		0.8349		0.8213		0.8213		42.0
#
#
#
#
# Sampling 31----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8571428571428572
#
#
# Confusion martix:  [[21.  0.]
#  [ 6. 15.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.78		1.0		0.88		21.0
# N2-Clean fact		1.0		0.71		0.83		21.0
# accuracy		nan		nan		0.86		42.0
# macro avg		0.89		0.86		0.85		42.0
# weighted avg		0.89		0.86		0.85		42.0
#
#
#
#
# Sampling 32----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8997619047619048
#
#
# Confusion martix:  [[20.    2.  ]
#  [ 2.21 17.79]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9016		0.91		0.9058		22.0
# N2-Clean fact		0.8979		0.8895		0.8937		20.0
# accuracy		nan		nan		0.8958		42.0
# macro avg		0.8958		0.8958		0.8958		42.0
# weighted avg		0.8958		0.8958		0.8958		42.0
#
#
#
#
# Sampling 33----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8159523809523809
#
#
# Confusion martix:  [[19.    4.  ]
#  [ 3.73 15.27]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8381		0.83		0.8327		23.0
# N2-Clean fact		0.7927		0.8035		0.7981		19.0
# accuracy		nan		nan		0.8154		42.0
# macro avg		0.8154		0.8154		0.8154		42.0
# weighted avg		0.8154		0.8154		0.8154		42.0
#
#
#
#
# Sampling 34----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8166666666666665
#
#
# Confusion martix:  [[19.   3. ]
#  [ 4.7 15.3]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.802		0.86		0.833		22.0
# N2-Clean fact		0.833		0.765		0.799		20.0
# accuracy		nan		nan		0.816		42.0
# macro avg		0.816		0.816		0.816		42.0
# weighted avg		0.816		0.816		0.816		42.0
#
#
#
#
# Sampling 35----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8645238095238095
#
#
# Confusion martix:  [[13.    1.  ]
#  [ 4.69 23.31]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7326		0.93		0.8202		14.0
# N2-Clean fact		0.96		0.8331		0.89		28.0
# accuracy		nan		nan		0.8653		42.0
# macro avg		0.8464		0.8824		0.8564		42.0
# weighted avg		0.8833		0.8653		0.8664		42.0
#
#
#
#
# Sampling 36----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8911904761904763
#
#
# Confusion martix:  [[20.    1.  ]
#  [ 3.57 17.43]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8472		0.95		0.8986		21.0
# N2-Clean fact		0.9438		0.831		0.8829		21.0
# accuracy		nan		nan		0.8891		42.0
# macro avg		0.8986		0.8891		0.8891		42.0
# weighted avg		0.8986		0.8891		0.8891		42.0
#
#
#
#
# Sampling 37----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.860952380952381
#
#
# Confusion martix:  [[17.    2.  ]
#  [ 3.84 19.16]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8164		0.89		0.8532		19.0
# N2-Clean fact		0.9031		0.8349		0.8663		23.0
# accuracy		nan		nan		0.8617		42.0
# macro avg		0.8632		0.8632		0.8617		42.0
# weighted avg		0.8632		0.8617		0.8617		42.0
#
#
#
#
# Sampling 38----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7380952380952382
#
#
# Confusion martix:  [[12. 10.]
#  [ 1. 19.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.92		0.55		0.69		22.0
# N2-Clean fact		0.66		0.95		0.78		20.0
# accuracy		nan		nan		0.74		42.0
# macro avg		0.79		0.75		0.73		42.0
# weighted avg		0.8		0.74		0.73		42.0
#
#
#
#
# Sampling 39----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7985714285714287
#
#
# Confusion martix:  [[15.37  2.63]
#  [ 5.83 18.17]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7223		0.8504		0.7845		18.0
# N2-Clean fact		0.8765		0.7568		0.8123		24.0
# accuracy		nan		nan		0.801		42.0
# macro avg		0.8027		0.8045		0.7945		42.0
# weighted avg		0.8127		0.801		0.801		42.0
#
#
#
#
# Sampling 40----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.870952380952381
#
#
# Confusion martix:  [[18.65  1.35]
#  [ 4.07 17.93]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8229		0.9325		0.8717		20.0
# N2-Clean fact		0.9309		0.8156		0.87		22.0
# accuracy		nan		nan		0.8704		42.0
# macro avg		0.8781		0.8724		0.8704		42.0
# weighted avg		0.8781		0.8704		0.8704		42.0
#
#
#
#
# Sampling 41----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9016666666666666
#
#
# Confusion martix:  [[23.    1.  ]
#  [ 3.13 14.87]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8772		0.96		0.9174		24.0
# N2-Clean fact		0.9376		0.8246		0.8761		18.0
# accuracy		nan		nan		0.8985		42.0
# macro avg		0.9074		0.895		0.8985		42.0
# weighted avg		0.9074		0.8985		0.8985		42.0
#
#
#
#
# Sampling 42----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8333333333333331
#
#
# Confusion martix:  [[16.  3.]
#  [ 4. 19.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8		0.84		0.82		19.0
# N2-Clean fact		0.86		0.83		0.84		23.0
# accuracy		nan		nan		0.83		42.0
# macro avg		0.83		0.83		0.83		42.0
# weighted avg		0.83		0.83		0.83		42.0
#
#
#
#
# Sampling 43----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8107142857142858
#
#
# Confusion martix:  [[16.    4.  ]
#  [ 3.95 18.05]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8026		0.8		0.801		20.0
# N2-Clean fact		0.8203		0.8199		0.8185		22.0
# accuracy		nan		nan		0.8108		42.0
# macro avg		0.8108		0.8106		0.8108		42.0
# weighted avg		0.8112		0.8108		0.8108		42.0
#
#
#
#
# Sampling 44----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.800952380952381
#
#
# Confusion martix:  [[16.8   5.2 ]
#  [ 3.16 16.84]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8417		0.762		0.8008		22.0
# N2-Clean fact		0.7624		0.842		0.8012		20.0
# accuracy		nan		nan		0.8024		42.0
# macro avg		0.8027		0.8026		0.8024		42.0
# weighted avg		0.8031		0.8024		0.8024		42.0
#
#
#
#
# Sampling 45----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.710238095238095
#
#
# Confusion martix:  [[13.    5.  ]
#  [ 7.17 16.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6449		0.72		0.6785		18.0
# N2-Clean fact		0.7683		0.7031		0.7349		24.0
# accuracy		nan		nan		0.7069		42.0
# macro avg		0.7066		0.7147		0.7066		42.0
# weighted avg		0.7166		0.7069		0.7147		42.0
#
#
#
#
# Sampling 46----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9009523809523808
#
#
# Confusion martix:  [[23.81  0.19]
#  [ 3.97 14.03]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.859		0.9924		0.917		24.0
# N2-Clean fact		0.9869		0.7811		0.8748		18.0
# accuracy		nan		nan		0.8973		42.0
# macro avg		0.9227		0.8871		0.8969		42.0
# weighted avg		0.9149		0.8973		0.8971		42.0
#
#
#
#
# Sampling 47----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6707142857142858
#
#
# Confusion martix:  [[12.    5.  ]
#  [ 8.83 16.17]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5762		0.71		0.6345		17.0
# N2-Clean fact		0.7617		0.6468		0.7023		25.0
# accuracy		nan		nan		0.6723		42.0
# macro avg		0.6734		0.6734		0.6662		42.0
# weighted avg		0.6845		0.6723		0.6734		42.0
#
#
#
#
# Sampling 48----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7433333333333333
#
#
# Confusion martix:  [[15.    2.  ]
#  [ 8.78 16.22]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6273		0.88		0.7344		17.0
# N2-Clean fact		0.8898		0.6488		0.7466		25.0
# accuracy		nan		nan		0.7442		42.0
# macro avg		0.762		0.7644		0.7437		42.0
# weighted avg		0.7846		0.7442		0.7442		42.0
#
#
#
#
# Sampling 49----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7119047619047617
#
#
# Confusion martix:  [[12.   4. ]
#  [ 8.1 17.9]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5972		0.75		0.668		16.0
# N2-Clean fact		0.819		0.6862		0.7472		26.0
# accuracy		nan		nan		0.7096		42.0
# macro avg		0.708		0.718		0.7078		42.0
# weighted avg		0.7364		0.7096		0.7156		42.0
#
#
#
#
# Sampling 50----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9285714285714287
#
#
# Confusion martix:  [[19.  1.]
#  [ 2. 20.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9		0.95		0.93		20.0
# N2-Clean fact		0.95		0.91		0.93		22.0
# accuracy		nan		nan		0.93		42.0
# macro avg		0.93		0.93		0.93		42.0
# weighted avg		0.93		0.93		0.93		42.0
#
#
#
#
# Sampling 51----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7197619047619045
#
#
# Confusion martix:  [[16.23  7.77]
#  [ 4.   14.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8023		0.6792		0.7366		24.0
# N2-Clean fact		0.6469		0.78		0.7046		18.0
# accuracy		nan		nan		0.7166		42.0
# macro avg		0.7246		0.7246		0.7166		42.0
# weighted avg		0.7346		0.7166		0.7246		42.0
#
#
#
#
# Sampling 52----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[14.  4.]
#  [ 4. 20.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.78		0.78		0.78		18.0
# N2-Clean fact		0.83		0.83		0.83		24.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.81		0.81		42.0
# weighted avg		0.81		0.81		0.81		42.0
#
#
#
#
# Sampling 53----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8033333333333335
#
#
# Confusion martix:  [[20.    3.  ]
#  [ 5.26 13.74]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7922		0.87		0.8285		23.0
# N2-Clean fact		0.8174		0.7233		0.7685		19.0
# accuracy		nan		nan		0.8048		42.0
# macro avg		0.8048		0.7959		0.8011		42.0
# weighted avg		0.8048		0.8048		0.8011		42.0
#
#
#
#
# Sampling 54----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7457142857142856
#
#
# Confusion martix:  [[16.    6.  ]
#  [ 4.68 15.32]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7728		0.73		0.7464		22.0
# N2-Clean fact		0.7164		0.766		0.7396		20.0
# accuracy		nan		nan		0.7464		42.0
# macro avg		0.7464		0.7464		0.7464		42.0
# weighted avg		0.7496		0.7464		0.7464		42.0
#
#
#
#
# Sampling 55----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8445238095238095
#
#
# Confusion martix:  [[23.    2.  ]
#  [ 4.53 12.47]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8341		0.92		0.8745		25.0
# N2-Clean fact		0.8647		0.7333		0.7888		17.0
# accuracy		nan		nan		0.8443		42.0
# macro avg		0.8494		0.8241		0.8341		42.0
# weighted avg		0.8492		0.8443		0.8441		42.0
#
#
#
#
# Sampling 56----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8073809523809525
#
#
# Confusion martix:  [[16.    5.  ]
#  [ 3.09 17.91]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8364		0.76		0.7982		21.0
# N2-Clean fact		0.7791		0.8555		0.8173		21.0
# accuracy		nan		nan		0.8082		42.0
# macro avg		0.8082		0.8082		0.8082		42.0
# weighted avg		0.8082		0.8082		0.8082		42.0
#
#
#
#
# Sampling 57----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7666666666666667
#
#
# Confusion martix:  [[15.   5. ]
#  [ 4.8 17.2]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.758		0.75		0.754		20.0
# N2-Clean fact		0.772		0.7814		0.776		22.0
# accuracy		nan		nan		0.7674		42.0
# macro avg		0.7674		0.764		0.764		42.0
# weighted avg		0.7674		0.7674		0.7674		42.0
#
#
#
#
# Sampling 58----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7654761904761904
#
#
# Confusion martix:  [[18.    5.  ]
#  [ 4.85 14.15]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.786		0.78		0.783		23.0
# N2-Clean fact		0.7415		0.7475		0.7445		19.0
# accuracy		nan		nan		0.7645		42.0
# macro avg		0.763		0.7645		0.763		42.0
# weighted avg		0.7645		0.7645		0.7645		42.0
#
#
#
#
# Sampling 59----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7871428571428574
#
#
# Confusion martix:  [[17.06  3.94]
#  [ 5.   16.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7706		0.813		0.7918		21.0
# N2-Clean fact		0.8024		0.76		0.7812		21.0
# accuracy		nan		nan		0.7912		42.0
# macro avg		0.7912		0.7912		0.7912		42.0
# weighted avg		0.7912		0.7912		0.7912		42.0
#
#
#
#
# Sampling 60----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[14.  5.]
#  [ 5. 18.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.74		0.74		0.74		19.0
# N2-Clean fact		0.78		0.78		0.78		23.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 61----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8061904761904762
#
#
# Confusion martix:  [[15.85  1.15]
#  [ 6.99 18.01]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6973		0.931		0.7957		17.0
# N2-Clean fact		0.9425		0.7204		0.8172		25.0
# accuracy		nan		nan		0.8072		42.0
# macro avg		0.8157		0.8257		0.8057		42.0
# weighted avg		0.8441		0.8072		0.8072		42.0
#
#
#
#
# Sampling 62----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8323809523809521
#
#
# Confusion martix:  [[19.    1.  ]
#  [ 6.04 15.96]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7588		0.95		0.841		20.0
# N2-Clean fact		0.94		0.7266		0.8188		22.0
# accuracy		nan		nan		0.8306		42.0
# macro avg		0.8492		0.8392		0.8306		42.0
# weighted avg		0.851		0.8306		0.8306		42.0
#
#
#
#
# Sampling 63----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.864047619047619
#
#
# Confusion martix:  [[19.    0.  ]
#  [ 5.71 17.29]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7687		1.0		0.8658		19.0
# N2-Clean fact		1.0		0.7516		0.8587		23.0
# accuracy		nan		nan		0.8646		42.0
# macro avg		0.887		0.8758		0.8646		42.0
# weighted avg		0.897		0.8646		0.8646		42.0
#
#
#
#
# Sampling 64----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7683333333333333
#
#
# Confusion martix:  [[17.    4.  ]
#  [ 5.73 15.27]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7484		0.81		0.7767		21.0
# N2-Clean fact		0.7927		0.7248		0.7581		21.0
# accuracy		nan		nan		0.7691		42.0
# macro avg		0.7691		0.7691		0.7691		42.0
# weighted avg		0.7691		0.7691		0.7691		42.0
#
#
#
#
# Sampling 65----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7197619047619048
#
#
# Confusion martix:  [[19.55  3.45]
#  [ 8.32 10.68]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7003		0.8505		0.7662		23.0
# N2-Clean fact		0.7614		0.5633		0.6445		19.0
# accuracy		nan		nan		0.7191		42.0
# macro avg		0.7307		0.7051		0.709		42.0
# weighted avg		0.7306		0.7191		0.7109		42.0
#
#
#
#
# Sampling 66----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8564285714285715
#
#
# Confusion martix:  [[19.    4.  ]
#  [ 2.03 16.97]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8988		0.83		0.8594		23.0
# N2-Clean fact		0.8097		0.8885		0.8491		19.0
# accuracy		nan		nan		0.8591		42.0
# macro avg		0.8591		0.8591		0.8591		42.0
# weighted avg		0.8591		0.8591		0.8591		42.0
#
#
#
#
# Sampling 67----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8471428571428572
#
#
# Confusion martix:  [[19.04  4.96]
#  [ 1.46 16.54]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9272		0.7918		0.8518		24.0
# N2-Clean fact		0.767		0.917		0.837		18.0
# accuracy		nan		nan		0.8472		42.0
# macro avg		0.8472		0.857		0.8472		42.0
# weighted avg		0.857		0.8472		0.8472		42.0
#
#
#
#
# Sampling 68----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8578571428571428
#
#
# Confusion martix:  [[17.91  3.09]
#  [ 2.88 18.12]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8639		0.8555		0.8597		21.0
# N2-Clean fact		0.8567		0.8648		0.8606		21.0
# accuracy		nan		nan		0.86		42.0
# macro avg		0.86		0.86		0.86		42.0
# weighted avg		0.86		0.86		0.86		42.0
#
#
#
#
# Sampling 69----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8802380952380955
#
#
# Confusion martix:  [[18.    3.  ]
#  [ 2.03 18.97]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8988		0.86		0.8794		21.0
# N2-Clean fact		0.86		0.8988		0.8794		21.0
# accuracy		nan		nan		0.8794		42.0
# macro avg		0.8794		0.8794		0.8794		42.0
# weighted avg		0.8794		0.8794		0.8794		42.0
#
#
#
#
# Sampling 70----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8628571428571428
#
#
# Confusion martix:  [[20.    2.  ]
#  [ 3.76 16.24]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8396		0.91		0.8748		22.0
# N2-Clean fact		0.89		0.812		0.8472		20.0
# accuracy		nan		nan		0.8648		42.0
# macro avg		0.8648		0.8572		0.8648		42.0
# weighted avg		0.8648		0.8648		0.8648		42.0
#
#
#
#
# Sampling 71----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6452380952380955
#
#
# Confusion martix:  [[12.   8. ]
#  [ 6.9 15.1]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.634		0.6		0.621		20.0
# N2-Clean fact		0.652		0.685		0.673		22.0
# accuracy		nan		nan		0.643		42.0
# macro avg		0.643		0.642		0.642		42.0
# weighted avg		0.643		0.643		0.643		42.0
#
#
#
#
# Sampling 72----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9047619047619047
#
#
# Confusion martix:  [[22.  2.]
#  [ 2. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.92		0.92		0.92		24.0
# N2-Clean fact		0.89		0.89		0.89		18.0
# accuracy		nan		nan		0.9		42.0
# macro avg		0.9		0.9		0.9		42.0
# weighted avg		0.9		0.9		0.9		42.0
#
#
#
#
# Sampling 73----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7404761904761906
#
#
# Confusion martix:  [[16.1  9.9]
#  [ 1.  15. ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9405		0.6235		0.743		26.0
# N2-Clean fact		0.6025		0.94		0.732		16.0
# accuracy		nan		nan		0.7425		42.0
# macro avg		0.7715		0.7815		0.742		42.0
# weighted avg		0.811		0.7425		0.7425		42.0
#
#
#
#
# Sampling 74----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8369047619047617
#
#
# Confusion martix:  [[17.    2.  ]
#  [ 4.85 18.15]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.776		0.89		0.833		19.0
# N2-Clean fact		0.9		0.7875		0.843		23.0
# accuracy		nan		nan		0.8345		42.0
# macro avg		0.843		0.843		0.8345		42.0
# weighted avg		0.843		0.8345		0.8345		42.0
#
#
#
#
# Sampling 75----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.725952380952381
#
#
# Confusion martix:  [[14.    6.  ]
#  [ 5.51 16.49]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7196		0.7		0.7098		20.0
# N2-Clean fact		0.7349		0.7496		0.7447		22.0
# accuracy		nan		nan		0.7247		42.0
# macro avg		0.7247		0.7247		0.7247		42.0
# weighted avg		0.7247		0.7247		0.7247		42.0
#
#
#
#
# Sampling 76----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8011904761904762
#
#
# Confusion martix:  [[14.    3.  ]
#  [ 5.35 19.65]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7262		0.82		0.773		17.0
# N2-Clean fact		0.8667		0.786		0.8229		25.0
# accuracy		nan		nan		0.8028		42.0
# macro avg		0.7931		0.803		0.7996		42.0
# weighted avg		0.813		0.8028		0.8028		42.0
#
#
#
#
# Sampling 77----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[19.  6.]
#  [ 4. 13.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.83		0.76		0.79		25.0
# N2-Clean fact		0.68		0.76		0.72		17.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.77		0.76		0.76		42.0
#
#
#
#
# Sampling 78----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9116666666666667
#
#
# Confusion martix:  [[1.899e+01 1.000e-02]
#  [3.700e+00 1.930e+01]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8389		0.9995		0.9088		19.0
# N2-Clean fact		0.9995		0.842		0.9088		23.0
# accuracy		nan		nan		0.9088		42.0
# macro avg		0.9157		0.9158		0.9088		42.0
# weighted avg		0.9257		0.9088		0.9088		42.0
#
#
#
#
# Sampling 79----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.923809523809524
#
#
# Confusion martix:  [[21.88  0.12]
#  [ 3.08 16.92]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8776		0.9946		0.9354		22.0
# N2-Clean fact		0.9934		0.846		0.9146		20.0
# accuracy		nan		nan		0.924		42.0
# macro avg		0.9348		0.924		0.924		42.0
# weighted avg		0.9348		0.924		0.924		42.0
#
#
#
#
# Sampling 80----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9407142857142857
#
#
# Confusion martix:  [[23.51  0.49]
#  [ 2.   16.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.92		0.9804		0.9502		24.0
# N2-Clean fact		0.9706		0.89		0.9253		18.0
# accuracy		nan		nan		0.9402		42.0
# macro avg		0.9453		0.9302		0.9402		42.0
# weighted avg		0.9453		0.9402		0.9402		42.0
#
#
#
#
# Sampling 81----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9757142857142859
#
#
# Confusion martix:  [[2.098e+01 2.000e-02]
#  [1.000e+00 2.000e+01]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.95		0.999		0.9794		21.0
# N2-Clean fact		0.999		0.95		0.9794		21.0
# accuracy		nan		nan		0.9794		42.0
# macro avg		0.9794		0.9794		0.9794		42.0
# weighted avg		0.9794		0.9794		0.9794		42.0
#
#
#
#
# Sampling 82----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8704761904761905
#
#
# Confusion martix:  [[15.57  2.43]
#  [ 3.01 20.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8353		0.8634		0.8469		18.0
# N2-Clean fact		0.8978		0.8795		0.8862		24.0
# accuracy		nan		nan		0.8711		42.0
# macro avg		0.8661		0.8669		0.8661		42.0
# weighted avg		0.872		0.8711		0.8719		42.0
#
#
#
#
# Sampling 83----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8809523809523812
#
#
# Confusion martix:  [[17.  3.]
#  [ 2. 20.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.89		0.85		0.87		20.0
# N2-Clean fact		0.87		0.91		0.89		22.0
# accuracy		nan		nan		0.88		42.0
# macro avg		0.88		0.88		0.88		42.0
# weighted avg		0.88		0.88		0.88		42.0
#
#
#
#
# Sampling 84----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.813095238095238
#
#
# Confusion martix:  [[18.    1.  ]
#  [ 6.85 16.15]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7245		0.95		0.823		19.0
# N2-Clean fact		0.94		0.706		0.8045		23.0
# accuracy		nan		nan		0.813		42.0
# macro avg		0.833		0.823		0.813		42.0
# weighted avg		0.843		0.813		0.813		42.0
#
#
#
#
# Sampling 85----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7647619047619046
#
#
# Confusion martix:  [[20.    3.  ]
#  [ 6.88 12.12]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7436		0.87		0.8024		23.0
# N2-Clean fact		0.8012		0.636		0.7134		19.0
# accuracy		nan		nan		0.7638		42.0
# macro avg		0.7724		0.7536		0.7538		42.0
# weighted avg		0.7724		0.7638		0.7622		42.0
#
#
#
#
# Sampling 86----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7464285714285716
#
#
# Confusion martix:  [[15.04  4.96]
#  [ 5.69 16.31]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7267		0.752		0.7374		20.0
# N2-Clean fact		0.7698		0.742		0.7551		22.0
# accuracy		nan		nan		0.7457		42.0
# macro avg		0.7459		0.7457		0.7457		42.0
# weighted avg		0.7489		0.7457		0.7457		42.0
#
#
#
#
# Sampling 87----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8035714285714286
#
#
# Confusion martix:  [[20.    2.  ]
#  [ 6.25 13.75]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7625		0.91		0.8275		22.0
# N2-Clean fact		0.8775		0.6875		0.77		20.0
# accuracy		nan		nan		0.805		42.0
# macro avg		0.815		0.795		0.8025		42.0
# weighted avg		0.815		0.805		0.8025		42.0
#
#
#
#
# Sampling 88----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.84
#
#
# Confusion martix:  [[16.69  2.31]
#  [ 4.41 18.59]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7915		0.8745		0.8325		19.0
# N2-Clean fact		0.8879		0.8092		0.8459		23.0
# accuracy		nan		nan		0.84		42.0
# macro avg		0.8431		0.8431		0.84		42.0
# weighted avg		0.8431		0.84		0.84		42.0
#
#
#
#
# Sampling 89----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5952380952380951
#
#
# Confusion martix:  [[11. 12.]
#  [ 5. 14.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.69		0.48		0.56		23.0
# N2-Clean fact		0.54		0.74		0.62		19.0
# accuracy		nan		nan		0.6		42.0
# macro avg		0.61		0.61		0.59		42.0
# weighted avg		0.62		0.6		0.59		42.0
#
#
#
#
# Sampling 90----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8809523809523812
#
#
# Confusion martix:  [[21.  2.]
#  [ 3. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.88		0.91		0.89		23.0
# N2-Clean fact		0.89		0.84		0.86		19.0
# accuracy		nan		nan		0.88		42.0
# macro avg		0.88		0.88		0.88		42.0
# weighted avg		0.88		0.88		0.88		42.0
#
#
#
#
# Sampling 91----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7490476190476191
#
#
# Confusion martix:  [[11.    1.  ]
#  [ 9.54 20.46]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5338		0.92		0.6792		12.0
# N2-Clean fact		0.9504		0.6838		0.7934		30.0
# accuracy		nan		nan		0.7496		42.0
# macro avg		0.745		0.7988		0.7392		42.0
# weighted avg		0.8346		0.7496		0.7596		42.0
#
#
#
#
# Sampling 92----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8790476190476191
#
#
# Confusion martix:  [[20.9   4.1 ]
#  [ 0.98 16.02]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9511		0.836		0.8884		25.0
# N2-Clean fact		0.7962		0.9412		0.8586		17.0
# accuracy		nan		nan		0.8784		42.0
# macro avg		0.8783		0.8886		0.8783		42.0
# weighted avg		0.8896		0.8784		0.8787		42.0
#
#
#
#
# Sampling 93----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8861904761904762
#
#
# Confusion martix:  [[18.    2.  ]
#  [ 2.78 19.22]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8689		0.9		0.8844		20.0
# N2-Clean fact		0.9035		0.8723		0.8879		22.0
# accuracy		nan		nan		0.8845		42.0
# macro avg		0.8845		0.8845		0.8845		42.0
# weighted avg		0.8845		0.8845		0.8845		42.0
#
#
#
#
# Sampling 94----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7921428571428573
#
#
# Confusion martix:  [[17.    4.  ]
#  [ 4.73 16.27]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7808		0.81		0.7954		21.0
# N2-Clean fact		0.8027		0.7735		0.7881		21.0
# accuracy		nan		nan		0.7954		42.0
# macro avg		0.7954		0.7954		0.7954		42.0
# weighted avg		0.7954		0.7954		0.7954		42.0
#
#
#
#
# Sampling 95----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7621428571428569
#
#
# Confusion martix:  [[21.97  3.03]
#  [ 6.96 10.04]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7609		0.8788		0.8102		25.0
# N2-Clean fact		0.769		0.5924		0.671		17.0
# accuracy		nan		nan		0.7606		42.0
# macro avg		0.7603		0.7306		0.7406		42.0
# weighted avg		0.7606		0.7606		0.7506		42.0
#
#
#
#
# Sampling 96----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8547619047619048
#
#
# Confusion martix:  [[14.33  2.67]
#  [ 3.43 21.57]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8061		0.8398		0.8233		17.0
# N2-Clean fact		0.8918		0.8628		0.8764		25.0
# accuracy		nan		nan		0.8551		42.0
# macro avg		0.8499		0.8513		0.85		42.0
# weighted avg		0.8578		0.8551		0.8551		42.0
#
#
#
#
# Sampling 97----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.814047619047619
#
#
# Confusion martix:  [[11.36  2.64]
#  [ 5.17 22.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6904		0.8152		0.741		14.0
# N2-Clean fact		0.8944		0.8149		0.8538		28.0
# accuracy		nan		nan		0.8138		42.0
# macro avg		0.7922		0.8126		0.7974		42.0
# weighted avg		0.8274		0.8138		0.8173		42.0
#
#
#
#
# Sampling 98----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9073809523809527
#
#
# Confusion martix:  [[20.9   1.1 ]
#  [ 2.79 17.21]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8849		0.9455		0.9117		22.0
# N2-Clean fact		0.9384		0.8605		0.8943		20.0
# accuracy		nan		nan		0.9047		42.0
# macro avg		0.9117		0.9047		0.9047		42.0
# weighted avg		0.9117		0.9047		0.9047		42.0
#
#
#
#
# Sampling 99----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9292857142857145
#
#
# Confusion martix:  [[17.02  1.98]
#  [ 0.99 22.01]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9408		0.8912		0.9208		19.0
# N2-Clean fact		0.9208		0.9604		0.9406		23.0
# accuracy		nan		nan		0.9306		42.0
# macro avg		0.9307		0.9306		0.9306		42.0
# weighted avg		0.9307		0.9306		0.9306		42.0
#
#
#
#
# Sampling 100----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7464285714285712
#
#
# Confusion martix:  [[14.    1.  ]
#  [ 9.65 17.35]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5923		0.93		0.727		15.0
# N2-Clean fact		0.9444		0.6434		0.7658		27.0
# accuracy		nan		nan		0.7458		42.0
# macro avg		0.7682		0.787		0.7455		42.0
# weighted avg		0.8235		0.7458		0.7514		42.0

# %%
final_ave_ConfusionMatrix=(np.round(np.average(conf_martix_ave_collect,axis=0))).astype(int)
print("Confusion Matrix\n",final_ave_ConfusionMatrix)
# Out:
# Confusion Matrix
#  [[17  4]
#  [ 4 17]]

# %%
class_names = ['1', '2']
fig, ax = plot_confusion_matrix(conf_mat=final_ave_ConfusionMatrix,
                                colorbar=True,
                                #show_absolute=False,
                                #show_normed=True,
                                class_names=class_names)
plt.show()

# %%
final_ave_ReportMatrix=np.round (np.average(report_matrix_ave_collect,axis=0),decimals=3)
print("Report Matrix\n",final_ave_ReportMatrix)
# Out:
# Report Matrix
#  [[ 0.798  0.831  0.808 20.88 ]
#  [ 0.831  0.794  0.806 21.12 ]
#  [   nan    nan  0.809 42.   ]
#  [ 0.815  0.813  0.807 42.   ]
#  [ 0.822  0.809  0.809 42.   ]]

# %% [markdown]
# ## 4.3 Improt preprocessed results (importance)

# %%
path_preprocessed_results="./RF_results_2L/preprocessed_results_sl3_2M_4L.csv"
preprocessed_results=np.array(pd.read_csv(path_preprocessed_results,header=None))
preprocessed_results.shape
# Out:
# (100, 10304)

# %% [markdown]
# ## 4.4 Compute the important features for each undersampling

# %%
groups=4
top_select=70

# %%
print("preprocessed_results.shape[0]",preprocessed_results.shape,"\n")

group_importance=[]
selected_feature_indices=[]

memebers=int(preprocessed_results.shape[0]/float(groups))
for group_i in np.arange(groups):
    group_importance_i=np.sum(preprocessed_results[group_i*memebers:(group_i+1)*memebers,:],axis=0)
    indices_i=np.argsort(group_importance_i)[::-1][0:top_select]
    
    group_importance.append(group_importance_i)
    selected_feature_indices.append(indices_i)
# Out:
# preprocessed_results.shape[0] (100, 10304)

# %%
for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.draw_with_importance(group_importance[group_i],original_edge_width,original_edge_length,top_select)
# Out:
# The number of group 0
# The number of group 1
# The number of group 2
# The number of group 3

# %%
F.draw_with_importance(np.mean(group_importance,axis=0),original_edge_width,original_edge_length,top_select)

# %% [markdown]
# ## 4.5 Compute the common important features from each undersampling

# %%
interect_indices=F.intersect_2Dlist(selected_feature_indices)
background=np.zeros(original_edge_length*original_edge_width)
background[F.intersect_2Dlist(selected_feature_indices)]=group_importance[0][interect_indices]

# %%
common_feature_catch=[]
for interect_indices_i in interect_indices:
    common_feature_catch.append([int(interect_indices_i/(original_edge_length)),interect_indices_i%(original_edge_length)])

for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.show_one_figure_with_keyfeature(group_importance[group_i],common_feature_catch,original_edge_width,original_edge_length)
    
F.show_one_figure_with_keyfeature(np.average(np.array(group_importance),axis=0),common_feature_catch,original_edge_width,original_edge_length)
# Out:
# The number of group 0
# The number of group 1
# The number of group 2
# The number of group 3

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length))
plt.axis('off')
plt.show()

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length),plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4.6 Show the common important features from each undersampling and comparing with the original key features

# %%
F.show_one_figure_with_keyfeature(Collect_noise_data.sum(axis=0),common_feature_catch,original_edge_width,original_edge_length)

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()
