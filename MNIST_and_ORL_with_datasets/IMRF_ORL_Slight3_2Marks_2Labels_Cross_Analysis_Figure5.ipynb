# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

#K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical,plot_model
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit,train_test_split,StratifiedKFold
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from skimage import io
from PIL import Image
import scipy.sparse as sparse
import pandas as pd
import random
import h5py
import math
import gc
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mlxtend.plotting import plot_confusion_matrix

# %matplotlib inline
matplotlib.style.use('ggplot')

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Parameters

# %%
dataset_path='./data/faces/ORL_Faces/'

original_edge_length=92
original_edge_width=112

black_area=4

number_samples_for_show=30

minority1=30
minority2=70
minority3=40
majority=90
sampling_times=100
seed_range=np.random.randint(100,size=100)#np.arange(0,100,1)
p_n_estimators=2100

# %% [markdown]
# # 3. Import data

# %% [markdown]
# ## 3.1 Loading data

# %%
points = {}

for dirpath, dirnames, filenames in os.walk(dataset_path):
    dirnames.sort()
    filenames.sort()
    for filename in [f for f in filenames if f.endswith(".pgm") and not f[0] == '.']:
        full_path = os.path.join(dirpath, filename)
        filename = full_path.split('/')[-1]
        file_identifier="%s" % (full_path.split('/')[-3])
        #print(file_identifier)
        if file_identifier not in points.keys():
            points[file_identifier] = []
        #image = io.imread(full_path)
        image_=Image.open(full_path).resize((original_edge_length, original_edge_width),Image.ANTIALIAS)
        image=np.asarray(image_)
        points[file_identifier].append(image)

#--------------------------------------------------------------------------------------------------------------------------------
Feature = []
for key in points.keys():
    for image_i in range(len(points[key])):
        Feature.append(np.array(points[key][image_i]))

Features=np.array(Feature)
rn.shuffle(Features)

Features_part1=Features[0:(400-minority1-minority2-minority3)]
Features_part2=Features[(400-minority1-minority2-minority3):(400-minority2-minority3)]
Features_part3=Features[(400-minority2-minority3):(400-minority3)]
Features_part4=Features[(400-minority3):]

Labels=np.r_[np.array([0]*(400-minority1-minority2-minority3)),np.array([1]*minority1),np.array([2]*minority2),np.array([3]*minority3)]

# %% [markdown]
# ## 3.2 Add noise to data

# %%
#--------------------------------------------------------------------------------------------------------------------------------
Collect1_noise_data=[]
for i in np.arange(400-minority1-minority2-minority3):
    Collect1_noise_data_i=np.zeros(Features_part2[1].shape)
    Collect1_noise_data.append(Collect1_noise_data_i)

#--------------------------------------------------------------------------------------------------------------------------------
Collect2_noise_data=[]
for i in np.arange(0,minority1):
    Features_part2_i=Features_part2[i]
    
    noise_data=Features_part2_i
    
    Collect2_noise_data_i=np.zeros(Features_part2[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)

for i in np.arange(0,minority2):
    Features_part3_i=Features_part3[i]
    
    noise_data=Features_part3_i
    
    Collect2_noise_data_i=np.zeros(Features_part3[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):         
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
    
for i in np.arange(0,minority3):
    Features_part4_i=Features_part4[i]
    
    noise_data=Features_part4_i
    
    Collect2_noise_data_i=np.zeros(Features_part4[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1   
            
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
#--------------------------------------------------------------------------------------------------------------------------------
Array_Feature = []
for i in np.arange(Features.shape[0]):
    Array_Feature.append(Features[i].flatten())

#--------------------------------------------------------------------------------------------------------------------------------
Collect_noise_data=np.array(Collect1_noise_data+Collect2_noise_data)
print('Shape of Collect_noise_data',Collect_noise_data.shape)
# Out:
# Shape of Collect_noise_data (400, 112, 92)

# %%
rand_indices = np.random.permutation(400)

Array_Feature_=np.array(Array_Feature)[rand_indices]
Labels_=np.array(Labels)[rand_indices]

# %% [markdown]
# ## 3.3 The number of samples for different classes

# %%
for i in np.arange(4):
    print(i,":",np.sum(Labels_==i))
# Out:
# 0 : 260
# 1 : 30
# 2 : 70
# 3 : 40

# %%
index_used=np.r_[np.where(Labels_==1)[0],np.where(Labels_==2)[0]]

Labels_used=Labels_[index_used]
Array_Feature_used=Array_Feature_[index_used]

# %% [markdown]
# ## 3.4 Do undersampling and generate multiple sample subsets

# %%
Samples_list=[]
Labels_for_Samples_list=[]
for time_i in np.arange(sampling_times):
    seed_i=time_i
    rus=RandomOverSampler(sampling_strategy={1:70,2:70},random_state=seed_i)
    Samples_,Labels_for_Samples_=rus.fit_sample(Array_Feature_used,Labels_used)
    Samples_list.append(Samples_)
    Labels_for_Samples_list.append(Labels_for_Samples_)

# %% [markdown]
# ## 3.5 Split training and testing samples

# %%
X_train_list=[]
X_test_list=[]
y_train_list=[]
y_test_list=[]

for time_i in np.arange(sampling_times):
    Samples_list_i_=Samples_list[time_i]
    Labels_for_Samples_i_=Labels_for_Samples_list[time_i]
    rand_indices = np.random.permutation(70+70)
    Samples_list_i=Samples_list_i_[rand_indices]
    Labels_for_Samples_i=Labels_for_Samples_i_[rand_indices]
    
    X_train_i,X_test_i, y_train_i, y_test_i =train_test_split(Samples_list_i,Labels_for_Samples_i,test_size=0.3, random_state=seed)

    print('Shape of X_train_i: ' + str(X_train_i.shape))
    print('Shape of y_train_i: ' + str(y_train_i.shape))
    print('Shape of X_test_i: ' + str(X_test_i.shape))
    print('Shape of y_test_i: ' + str(y_test_i.shape))
    
    X_train_list.append(X_train_i)
    X_test_list.append(X_test_i)
    y_train_list.append(y_train_i)
    y_test_list.append(y_test_i)
    
    print("\n======================================================\n\n")
# Out:
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================
#
#
# Shape of X_train_i: (98, 10304)
# Shape of y_train_i: (98,)
# Shape of X_test_i: (42, 10304)
# Shape of y_test_i: (42,)
#
# ======================================================

# %% [markdown]
# ## 3.6 Display training and testing samples

# %%
F.show_data_figures(np.array(X_train_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)
# Out:
# ./Defined/Functions.py:71: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(p_pad,p_w_pad, p_h_pad)

# %%
y_train_list[0][0:number_samples_for_show]
# Out:
# array([1, 2, 2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 2,
#        2, 1, 2, 2, 1, 2, 1, 2])

# %%
F.show_data_figures(np.array(X_train_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2,
#        1, 1, 2, 1, 2, 1, 2, 1])

# %%
F.show_data_figures(np.array(X_test_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_test_list[0][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 2, 2, 2, 2, 1, 1, 1, 1, 2, 2, 1, 2, 2, 2, 1, 1, 1, 2,
#        2, 2, 1, 2, 1, 1, 2, 1])

# %%
F.show_data_figures(np.array(X_test_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([1, 1, 1, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2,
#        1, 1, 2, 1, 2, 1, 2, 1])

# %% [markdown]
# # 4 Analysis

# %% [markdown]
# ## 4.1 Improt predicated results

# %%
path_predicated_results="./RF_results_2L/predicated_results_sl3_2M_4L_Cross.csv"
predicated_results=pd.read_csv(path_predicated_results, sep='delimiter', header=None)
class_names=["N1-Clean fact","N2-Clean fact"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %% [markdown]
# ## 4.2 Average accuarcy and confusion matrix

# %%
time_i=int(predicated_results.shape[0]/(4*len(seed_range)))
print("The number of samplings: ",time_i)

Acc_train_ave_collect=[]
Acc_test_ave_collect=[]
conf_martix_ave_collect=[]
report_matrix_ave_collect=[]

for time_i in np.arange(time_i):
    print("Sampling "+str(time_i+1)+"----------------------------------------------------------------------------------\n")
    
    Acc_train_list=[]
    Acc_test_list=[]

    conf_martix=[]
    report_matrix=[]

    for pred_i in np.arange(len(seed_range)*time_i,len(seed_range)*(time_i+1)):
    
        Acc_train=np.array(predicated_results)[4*pred_i]
        Acc_test=np.array(predicated_results)[4*pred_i+1]
        p_y_pred=np.array(predicated_results)[4*pred_i+2]
        p_y_test=np.array(predicated_results)[4*pred_i+3]
        
        Acc_train_list.append(Acc_train)
        Acc_test_list.append(Acc_test)
    
        pred_set=np.array(p_y_pred[0].split(",")).astype(float)
        truth_set=np.array(p_y_test[0].split(",")).astype(float)

        conf_martix_i = np.array(confusion_matrix(truth_set, pred_set))
        conf_martix.append(conf_martix_i)

        report = classification_report(truth_set, pred_set)
        report_matrix_i=[]
        report_matrix_i.append(np.array(report.split('\n')[2].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[3].split()[1:]).astype(float))
        report_matrix_i.append(np.array(['nan','nan']+report.split('\n')[5].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[6].split()[2:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[7].split()[2:]).astype(float))

        report_matrix.append(np.array(report_matrix_i))
    
    # Accuarcy---------------------------------------------------------------------------------------------------------
    Acc_train_ave=np.average(np.array(Acc_train_list).astype(float))
    Acc_test_ave=np.average(np.array(Acc_test_list).astype(float))
    print("Acc_train_ave: ",Acc_train_ave)
    print("Acc_test_ave: ",Acc_test_ave)
    print('\n')

    Acc_train_ave_collect.append(Acc_train_ave)
    Acc_test_ave_collect.append(Acc_test_ave)
    
    # Confusion martix---------------------------------------------------------------------------------------------------------
    conf_martix_ave=np.average(conf_martix,axis=0)
    print("Confusion martix: ",conf_martix_ave)
    print('\n')

    conf_martix_ave_collect.append(conf_martix_ave)

    # Report---------------------------------------------------------------------------------------------------------
    report_matrix_ave=np.average(report_matrix,axis=0)
    Title=np.array(['Classes']+report.split('\n')[0].split()).reshape(1,5)
    report_matrix_ave_=np.c_[np.array(class_names+['accuracy','macro avg','weighted avg']),np.round(report_matrix_ave,decimals=4).astype(str)]

    report_matrix_ave_mergetitle=np.r_[np.array(Title),report_matrix_ave_]

    for i in report_matrix_ave_mergetitle:
        print('\t\t'.join(i))
        
    report_matrix_ave_collect.append(report_matrix_ave)
    
    print("\n\n\n")
# Out:
# The number of samplings:  100
# Sampling 1----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7876190476190479
#
#
# Confusion martix:  [[17.01  3.99]
#  [ 4.93 16.07]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7733		0.8105		0.7917		21.0
# N2-Clean fact		0.8011		0.7635		0.7823		21.0
# accuracy		nan		nan		0.7912		42.0
# macro avg		0.7912		0.7912		0.7912		42.0
# weighted avg		0.7912		0.7912		0.7912		42.0
#
#
#
#
# Sampling 2----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6423809523809527
#
#
# Confusion martix:  [[11.    7.  ]
#  [ 8.02 15.98]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5794		0.61		0.5899		18.0
# N2-Clean fact		0.6995		0.6689		0.6794		24.0
# accuracy		nan		nan		0.6397		42.0
# macro avg		0.6396		0.6396		0.6396		42.0
# weighted avg		0.6496		0.6397		0.6397		42.0
#
#
#
#
# Sampling 3----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8326190476190477
#
#
# Confusion martix:  [[17.    1.  ]
#  [ 6.03 17.97]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7392		0.94		0.8294		18.0
# N2-Clean fact		0.948		0.7488		0.8375		24.0
# accuracy		nan		nan		0.831		42.0
# macro avg		0.8414		0.8494		0.831		42.0
# weighted avg		0.8578		0.831		0.831		42.0
#
#
#
#
# Sampling 4----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7983333333333336
#
#
# Confusion martix:  [[21.    2.  ]
#  [ 6.47 12.53]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7659		0.91		0.8309		23.0
# N2-Clean fact		0.865		0.6576		0.7464		19.0
# accuracy		nan		nan		0.8003		42.0
# macro avg		0.8112		0.7854		0.7911		42.0
# weighted avg		0.8106		0.8003		0.7948		42.0
#
#
#
#
# Sampling 5----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[17.  3.]
#  [ 5. 17.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.77		0.85		0.81		20.0
# N2-Clean fact		0.85		0.77		0.81		22.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.81		0.81		42.0
# weighted avg		0.81		0.81		0.81		42.0
#
#
#
#
# Sampling 6----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7714285714285716
#
#
# Confusion martix:  [[16.   3. ]
#  [ 6.6 16.4]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.712		0.84		0.768		19.0
# N2-Clean fact		0.844		0.716		0.772		23.0
# accuracy		nan		nan		0.772		42.0
# macro avg		0.778		0.778		0.772		42.0
# weighted avg		0.784		0.772		0.772		42.0
#
#
#
#
# Sampling 7----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[15.  5.]
#  [ 5. 17.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.75		0.75		0.75		20.0
# N2-Clean fact		0.77		0.77		0.77		22.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 8----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[21.  5.]
#  [ 5. 11.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.81		0.81		0.81		26.0
# N2-Clean fact		0.69		0.69		0.69		16.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.75		0.75		0.75		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 9----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9047619047619047
#
#
# Confusion martix:  [[22.  3.]
#  [ 1. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.96		0.88		0.92		25.0
# N2-Clean fact		0.84		0.94		0.89		17.0
# accuracy		nan		nan		0.9		42.0
# macro avg		0.9		0.91		0.9		42.0
# weighted avg		0.91		0.9		0.91		42.0
#
#
#
#
# Sampling 10----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7509523809523811
#
#
# Confusion martix:  [[10.31  9.69]
#  [ 0.77 21.23]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9306		0.5155		0.6625		20.0
# N2-Clean fact		0.69		0.9615		0.8019		22.0
# accuracy		nan		nan		0.7505		42.0
# macro avg		0.8081		0.7398		0.733		42.0
# weighted avg		0.8045		0.7505		0.733		42.0
#
#
#
#
# Sampling 11----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7704761904761903
#
#
# Confusion martix:  [[17.    8.  ]
#  [ 1.64 15.36]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.908		0.68		0.7772		25.0
# N2-Clean fact		0.6572		0.9016		0.7608		17.0
# accuracy		nan		nan		0.7708		42.0
# macro avg		0.7844		0.7908		0.7708		42.0
# weighted avg		0.8108		0.7708		0.7708		42.0
#
#
#
#
# Sampling 12----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.840238095238095
#
#
# Confusion martix:  [[18.    2.  ]
#  [ 4.71 17.29]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7931		0.9		0.8458		20.0
# N2-Clean fact		0.8944		0.786		0.8387		22.0
# accuracy		nan		nan		0.8402		42.0
# macro avg		0.8458		0.8443		0.8402		42.0
# weighted avg		0.8458		0.8402		0.8402		42.0
#
#
#
#
# Sampling 13----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8571428571428572
#
#
# Confusion martix:  [[24.  2.]
#  [ 4. 12.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.86		0.92		0.89		26.0
# N2-Clean fact		0.86		0.75		0.8		16.0
# accuracy		nan		nan		0.86		42.0
# macro avg		0.86		0.84		0.84		42.0
# weighted avg		0.86		0.86		0.86		42.0
#
#
#
#
# Sampling 14----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9047619047619047
#
#
# Confusion martix:  [[22.  0.]
#  [ 4. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8499		1.0		0.92		22.0
# N2-Clean fact		1.0		0.8		0.89		20.0
# accuracy		nan		nan		0.9001		42.0
# macro avg		0.9201		0.9001		0.9001		42.0
# weighted avg		0.92		0.9001		0.9001		42.0
#
#
#
#
# Sampling 15----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8733333333333334
#
#
# Confusion martix:  [[22.    4.  ]
#  [ 1.32 14.68]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9472		0.85		0.8936		26.0
# N2-Clean fact		0.7868		0.9208		0.8472		16.0
# accuracy		nan		nan		0.8736		42.0
# macro avg		0.8636		0.8804		0.8704		42.0
# weighted avg		0.8804		0.8736		0.8736		42.0
#
#
#
#
# Sampling 16----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7378571428571431
#
#
# Confusion martix:  [[14.    8.  ]
#  [ 3.01 16.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8196		0.64		0.7198		22.0
# N2-Clean fact		0.6799		0.8495		0.7597		20.0
# accuracy		nan		nan		0.7397		42.0
# macro avg		0.7497		0.7398		0.7397		42.0
# weighted avg		0.7596		0.7397		0.7397		42.0
#
#
#
#
# Sampling 17----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7642857142857145
#
#
# Confusion martix:  [[16.   2. ]
#  [ 7.9 16.1]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.673		0.89		0.762		18.0
# N2-Clean fact		0.89		0.674		0.763		24.0
# accuracy		nan		nan		0.763		42.0
# macro avg		0.782		0.782		0.763		42.0
# weighted avg		0.792		0.763		0.763		42.0
#
#
#
#
# Sampling 18----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7380952380952382
#
#
# Confusion martix:  [[17.  2.]
#  [ 9. 14.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.65		0.89		0.76		19.0
# N2-Clean fact		0.88		0.61		0.72		23.0
# accuracy		nan		nan		0.74		42.0
# macro avg		0.76		0.75		0.74		42.0
# weighted avg		0.77		0.74		0.73		42.0
#
#
#
#
# Sampling 19----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8333333333333331
#
#
# Confusion martix:  [[20.  7.]
#  [ 0. 15.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		1.0		0.74		0.85		27.0
# N2-Clean fact		0.68		1.0		0.81		15.0
# accuracy		nan		nan		0.83		42.0
# macro avg		0.84		0.87		0.83		42.0
# weighted avg		0.89		0.83		0.84		42.0
#
#
#
#
# Sampling 20----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7502380952380951
#
#
# Confusion martix:  [[14.   10.  ]
#  [ 0.49 17.51]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9657		0.58		0.7302		24.0
# N2-Clean fact		0.6351		0.9706		0.7702		18.0
# accuracy		nan		nan		0.7502		42.0
# macro avg		0.8004		0.7753		0.7502		42.0
# weighted avg		0.8255		0.7502		0.7453		42.0
#
#
#
#
# Sampling 21----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6433333333333335
#
#
# Confusion martix:  [[14.02  8.98]
#  [ 6.   13.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7003		0.6109		0.6506		23.0
# N2-Clean fact		0.5906		0.68		0.6304		19.0
# accuracy		nan		nan		0.6405		42.0
# macro avg		0.6504		0.6504		0.6405		42.0
# weighted avg		0.6504		0.6405		0.6405		42.0
#
#
#
#
# Sampling 22----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8226190476190476
#
#
# Confusion martix:  [[15.8   2.2 ]
#  [ 5.25 18.75]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7506		0.876		0.809		18.0
# N2-Clean fact		0.9006		0.78		0.8345		24.0
# accuracy		nan		nan		0.824		42.0
# macro avg		0.8236		0.8294		0.8213		42.0
# weighted avg		0.8351		0.824		0.824		42.0
#
#
#
#
# Sampling 23----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7107142857142857
#
#
# Confusion martix:  [[17.    3.  ]
#  [ 9.15 12.85]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6493		0.85		0.7374		20.0
# N2-Clean fact		0.8085		0.5853		0.6768		22.0
# accuracy		nan		nan		0.709		42.0
# macro avg		0.7277		0.7173		0.7083		42.0
# weighted avg		0.7367		0.709		0.7059		42.0
#
#
#
#
# Sampling 24----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7564285714285716
#
#
# Confusion martix:  [[16.15  6.85]
#  [ 3.38 15.62]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8263		0.706		0.7569		23.0
# N2-Clean fact		0.6969		0.821		0.7516		19.0
# accuracy		nan		nan		0.7564		42.0
# macro avg		0.7616		0.7616		0.7564		42.0
# weighted avg		0.7706		0.7564		0.7564		42.0
#
#
#
#
# Sampling 25----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7488095238095239
#
#
# Confusion martix:  [[18.    5.  ]
#  [ 5.55 13.45]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7635		0.78		0.7745		23.0
# N2-Clean fact		0.729		0.707		0.718		19.0
# accuracy		nan		nan		0.749		42.0
# macro avg		0.749		0.7435		0.7435		42.0
# weighted avg		0.749		0.749		0.749		42.0
#
#
#
#
# Sampling 26----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7283333333333332
#
#
# Confusion martix:  [[13.    8.  ]
#  [ 3.41 17.59]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7895		0.62		0.6918		21.0
# N2-Clean fact		0.6859		0.8395		0.7577		21.0
# accuracy		nan		nan		0.7277		42.0
# macro avg		0.7377		0.7277		0.7218		42.0
# weighted avg		0.7377		0.7277		0.7218		42.0
#
#
#
#
# Sampling 27----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8807142857142858
#
#
# Confusion martix:  [[16.    3.  ]
#  [ 2.01 20.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8895		0.84		0.8598		19.0
# N2-Clean fact		0.8799		0.9096		0.8898		23.0
# accuracy		nan		nan		0.8798		42.0
# macro avg		0.8798		0.8798		0.8798		42.0
# weighted avg		0.8798		0.8798		0.8798		42.0
#
#
#
#
# Sampling 28----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8757142857142859
#
#
# Confusion martix:  [[17.    3.  ]
#  [ 2.22 19.78]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8817		0.85		0.8656		20.0
# N2-Clean fact		0.8679		0.8986		0.883		22.0
# accuracy		nan		nan		0.8755		42.0
# macro avg		0.876		0.8755		0.8755		42.0
# weighted avg		0.876		0.8755		0.8755		42.0
#
#
#
#
# Sampling 29----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[18.  6.]
#  [ 2. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9		0.75		0.82		24.0
# N2-Clean fact		0.73		0.89		0.8		18.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.82		0.81		42.0
# weighted avg		0.83		0.81		0.81		42.0
#
#
#
#
# Sampling 30----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8323809523809521
#
#
# Confusion martix:  [[15.84  2.16]
#  [ 4.88 19.12]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7648		0.8804		0.8176		18.0
# N2-Clean fact		0.8961		0.7948		0.8425		24.0
# accuracy		nan		nan		0.8314		42.0
# macro avg		0.8296		0.8376		0.8313		42.0
# weighted avg		0.8396		0.8314		0.8314		42.0
#
#
#
#
# Sampling 31----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8571428571428572
#
#
# Confusion martix:  [[21.  0.]
#  [ 6. 15.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.78		1.0		0.88		21.0
# N2-Clean fact		1.0		0.71		0.83		21.0
# accuracy		nan		nan		0.86		42.0
# macro avg		0.89		0.86		0.85		42.0
# weighted avg		0.89		0.86		0.85		42.0
#
#
#
#
# Sampling 32----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9
#
#
# Confusion martix:  [[20.   2. ]
#  [ 2.2 17.8]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.902		0.91		0.906		22.0
# N2-Clean fact		0.898		0.89		0.894		20.0
# accuracy		nan		nan		0.896		42.0
# macro avg		0.896		0.896		0.896		42.0
# weighted avg		0.896		0.896		0.896		42.0
#
#
#
#
# Sampling 33----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8192857142857142
#
#
# Confusion martix:  [[19.    4.  ]
#  [ 3.59 15.41]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8423		0.83		0.8341		23.0
# N2-Clean fact		0.7941		0.8105		0.8023		19.0
# accuracy		nan		nan		0.8182		42.0
# macro avg		0.8182		0.8182		0.8182		42.0
# weighted avg		0.8182		0.8182		0.8182		42.0
#
#
#
#
# Sampling 34----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8161904761904762
#
#
# Confusion martix:  [[19.    3.  ]
#  [ 4.72 15.28]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8012		0.86		0.8328		22.0
# N2-Clean fact		0.8328		0.764		0.7984		20.0
# accuracy		nan		nan		0.8156		42.0
# macro avg		0.8156		0.8156		0.8156		42.0
# weighted avg		0.8156		0.8156		0.8156		42.0
#
#
#
#
# Sampling 35----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8669047619047617
#
#
# Confusion martix:  [[13.    1.  ]
#  [ 4.59 23.41]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7364		0.93		0.823		14.0
# N2-Clean fact		0.96		0.8371		0.893		28.0
# accuracy		nan		nan		0.8675		42.0
# macro avg		0.8482		0.8834		0.8582		42.0
# weighted avg		0.8841		0.8675		0.8682		42.0
#
#
#
#
# Sampling 36----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9007142857142857
#
#
# Confusion martix:  [[20.    1.  ]
#  [ 3.17 17.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8632		0.95		0.9066		21.0
# N2-Clean fact		0.9457		0.8492		0.8946		21.0
# accuracy		nan		nan		0.8989		42.0
# macro avg		0.9066		0.8989		0.8989		42.0
# weighted avg		0.9066		0.8989		0.8989		42.0
#
#
#
#
# Sampling 37----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8657142857142857
#
#
# Confusion martix:  [[17.    2.  ]
#  [ 3.64 19.36]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8244		0.89		0.8572		19.0
# N2-Clean fact		0.9045		0.8435		0.8717		23.0
# accuracy		nan		nan		0.8663		42.0
# macro avg		0.8672		0.8672		0.8663		42.0
# weighted avg		0.8672		0.8663		0.8663		42.0
#
#
#
#
# Sampling 38----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7380952380952382
#
#
# Confusion martix:  [[12. 10.]
#  [ 1. 19.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.92		0.55		0.69		22.0
# N2-Clean fact		0.66		0.95		0.78		20.0
# accuracy		nan		nan		0.74		42.0
# macro avg		0.79		0.75		0.73		42.0
# weighted avg		0.8		0.74		0.73		42.0
#
#
#
#
# Sampling 39----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8069047619047619
#
#
# Confusion martix:  [[15.32  2.68]
#  [ 5.43 18.57]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7366		0.8479		0.791		18.0
# N2-Clean fact		0.8747		0.7728		0.8218		24.0
# accuracy		nan		nan		0.8087		42.0
# macro avg		0.8095		0.811		0.8046		42.0
# weighted avg		0.8162		0.8087		0.8087		42.0
#
#
#
#
# Sampling 40----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8692857142857143
#
#
# Confusion martix:  [[18.61  1.39]
#  [ 4.1  17.9 ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.822		0.9305		0.8703		20.0
# N2-Clean fact		0.9295		0.815		0.8692		22.0
# accuracy		nan		nan		0.8695		42.0
# macro avg		0.8763		0.8703		0.8695		42.0
# weighted avg		0.8763		0.8695		0.8695		42.0
#
#
#
#
# Sampling 41----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8926190476190476
#
#
# Confusion martix:  [[23.    1.  ]
#  [ 3.51 14.49]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.865		0.96		0.9098		24.0
# N2-Clean fact		0.9346		0.8048		0.8647		18.0
# accuracy		nan		nan		0.8901		42.0
# macro avg		0.8998		0.8844		0.8901		42.0
# weighted avg		0.8998		0.8901		0.8901		42.0
#
#
#
#
# Sampling 42----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8328571428571426
#
#
# Confusion martix:  [[15.98  3.02]
#  [ 4.   19.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7998		0.839		0.8194		19.0
# N2-Clean fact		0.8594		0.83		0.8398		23.0
# accuracy		nan		nan		0.8296		42.0
# macro avg		0.8296		0.8296		0.8296		42.0
# weighted avg		0.8296		0.8296		0.8296		42.0
#
#
#
#
# Sampling 43----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8097619047619047
#
#
# Confusion martix:  [[15.98  4.02]
#  [ 3.97 18.03]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8015		0.799		0.8		20.0
# N2-Clean fact		0.8194		0.8188		0.8174		22.0
# accuracy		nan		nan		0.8099		42.0
# macro avg		0.8099		0.8096		0.8097		42.0
# weighted avg		0.8103		0.8099		0.8099		42.0
#
#
#
#
# Sampling 44----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8023809523809526
#
#
# Confusion martix:  [[16.65  5.35]
#  [ 2.95 17.05]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8486		0.756		0.8005		22.0
# N2-Clean fact		0.76		0.8525		0.8045		20.0
# accuracy		nan		nan		0.804		42.0
# macro avg		0.8046		0.8045		0.804		42.0
# weighted avg		0.8046		0.804		0.804		42.0
#
#
#
#
# Sampling 45----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7123809523809521
#
#
# Confusion martix:  [[13.    5.  ]
#  [ 7.08 16.92]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6476		0.72		0.6797		18.0
# N2-Clean fact		0.7692		0.7068		0.7376		24.0
# accuracy		nan		nan		0.7089		42.0
# macro avg		0.7084		0.7171		0.7084		42.0
# weighted avg		0.7184		0.7089		0.7171		42.0
#
#
#
#
# Sampling 46----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8966666666666666
#
#
# Confusion martix:  [[23.67  0.33]
#  [ 4.01 13.99]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8564		0.9868		0.9138		24.0
# N2-Clean fact		0.9773		0.7786		0.8689		18.0
# accuracy		nan		nan		0.8936		42.0
# macro avg		0.9165		0.8831		0.8927		42.0
# weighted avg		0.9099		0.8936		0.8933		42.0
#
#
#
#
# Sampling 47----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6704761904761906
#
#
# Confusion martix:  [[12.    5.  ]
#  [ 8.84 16.16]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5759		0.71		0.6343		17.0
# N2-Clean fact		0.7616		0.6464		0.7022		25.0
# accuracy		nan		nan		0.6721		42.0
# macro avg		0.6732		0.6732		0.6658		42.0
# weighted avg		0.6843		0.6721		0.6733		42.0
#
#
#
#
# Sampling 48----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7433333333333334
#
#
# Confusion martix:  [[15.    2.  ]
#  [ 8.78 16.22]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6266		0.88		0.7344		17.0
# N2-Clean fact		0.89		0.6488		0.7466		25.0
# accuracy		nan		nan		0.7444		42.0
# macro avg		0.7622		0.7644		0.7444		42.0
# weighted avg		0.7844		0.7444		0.7444		42.0
#
#
#
#
# Sampling 49----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7095238095238093
#
#
# Confusion martix:  [[12.   4. ]
#  [ 8.2 17.8]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5944		0.75		0.666		16.0
# N2-Clean fact		0.818		0.6824		0.7444		26.0
# accuracy		nan		nan		0.7065		42.0
# macro avg		0.706		0.716		0.7056		42.0
# weighted avg		0.7355		0.7065		0.7139		42.0
#
#
#
#
# Sampling 50----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9242857142857145
#
#
# Confusion martix:  [[19.    1.  ]
#  [ 2.18 19.82]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8928		0.95		0.9246		20.0
# N2-Clean fact		0.95		0.901		0.9246		22.0
# accuracy		nan		nan		0.9246		42.0
# macro avg		0.9264		0.9264		0.9246		42.0
# weighted avg		0.9264		0.9246		0.9246		42.0
#
#
#
#
# Sampling 51----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7173809523809521
#
#
# Confusion martix:  [[16.13  7.87]
#  [ 4.   14.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8013		0.6752		0.7338		24.0
# N2-Clean fact		0.6439		0.78		0.7026		18.0
# accuracy		nan		nan		0.7138		42.0
# macro avg		0.7226		0.7226		0.7138		42.0
# weighted avg		0.7326		0.7138		0.7226		42.0
#
#
#
#
# Sampling 52----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8095238095238096
#
#
# Confusion martix:  [[14.  4.]
#  [ 4. 20.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.78		0.78		0.78		18.0
# N2-Clean fact		0.83		0.83		0.83		24.0
# accuracy		nan		nan		0.81		42.0
# macro avg		0.81		0.81		0.81		42.0
# weighted avg		0.81		0.81		0.81		42.0
#
#
#
#
# Sampling 53----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7980952380952381
#
#
# Confusion martix:  [[20.    3.  ]
#  [ 5.48 13.52]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7856		0.87		0.8259		23.0
# N2-Clean fact		0.8152		0.7105		0.7601		19.0
# accuracy		nan		nan		0.7998		42.0
# macro avg		0.8004		0.7911		0.7943		42.0
# weighted avg		0.8004		0.7998		0.7949		42.0
#
#
#
#
# Sampling 54----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7421428571428571
#
#
# Confusion martix:  [[16.    6.  ]
#  [ 4.83 15.17]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7668		0.73		0.7434		22.0
# N2-Clean fact		0.7134		0.7585		0.7351		20.0
# accuracy		nan		nan		0.7434		42.0
# macro avg		0.7434		0.7434		0.7434		42.0
# weighted avg		0.7451		0.7434		0.7434		42.0
#
#
#
#
# Sampling 55----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8480952380952381
#
#
# Confusion martix:  [[23.    2.  ]
#  [ 4.38 12.62]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8386		0.92		0.876		25.0
# N2-Clean fact		0.8662		0.7408		0.7948		17.0
# accuracy		nan		nan		0.8488		42.0
# macro avg		0.8524		0.8286		0.8386		42.0
# weighted avg		0.8522		0.8488		0.8486		42.0
#
#
#
#
# Sampling 56----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.807857142857143
#
#
# Confusion martix:  [[16.    5.  ]
#  [ 3.07 17.93]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8372		0.76		0.7986		21.0
# N2-Clean fact		0.7793		0.8565		0.8179		21.0
# accuracy		nan		nan		0.8086		42.0
# macro avg		0.8086		0.8086		0.8086		42.0
# weighted avg		0.8086		0.8086		0.8086		42.0
#
#
#
#
# Sampling 57----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7578571428571429
#
#
# Confusion martix:  [[15.    5.  ]
#  [ 5.17 16.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7439		0.75		0.7466		20.0
# N2-Clean fact		0.7683		0.7651		0.7649		22.0
# accuracy		nan		nan		0.7585		42.0
# macro avg		0.7592		0.7566		0.7559		42.0
# weighted avg		0.7592		0.7585		0.7585		42.0
#
#
#
#
# Sampling 58----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7626190476190474
#
#
# Confusion martix:  [[18.    5.  ]
#  [ 4.97 14.03]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7812		0.78		0.7806		23.0
# N2-Clean fact		0.7403		0.7415		0.7409		19.0
# accuracy		nan		nan		0.7609		42.0
# macro avg		0.7606		0.7609		0.7606		42.0
# weighted avg		0.7609		0.7609		0.7609		42.0
#
#
#
#
# Sampling 59----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7873809523809527
#
#
# Confusion martix:  [[17.    4.  ]
#  [ 4.93 16.07]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7728		0.81		0.7914		21.0
# N2-Clean fact		0.8007		0.7635		0.7821		21.0
# accuracy		nan		nan		0.7914		42.0
# macro avg		0.7914		0.7914		0.7914		42.0
# weighted avg		0.7914		0.7914		0.7914		42.0
#
#
#
#
# Sampling 60----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[14.  5.]
#  [ 5. 18.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.74		0.74		0.74		19.0
# N2-Clean fact		0.78		0.78		0.78		23.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.76		0.76		0.76		42.0
#
#
#
#
# Sampling 61----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8064285714285715
#
#
# Confusion martix:  [[15.68  1.32]
#  [ 6.81 18.19]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6993		0.9208		0.7942		17.0
# N2-Clean fact		0.934		0.7276		0.8185		25.0
# accuracy		nan		nan		0.8074		42.0
# macro avg		0.8142		0.8242		0.8053		42.0
# weighted avg		0.8402		0.8074		0.8074		42.0
#
#
#
#
# Sampling 62----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8340476190476189
#
#
# Confusion martix:  [[19.    1.  ]
#  [ 5.97 16.03]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7609		0.95		0.8423		20.0
# N2-Clean fact		0.94		0.7295		0.8209		22.0
# accuracy		nan		nan		0.8326		42.0
# macro avg		0.8506		0.8406		0.8326		42.0
# weighted avg		0.8523		0.8326		0.8326		42.0
#
#
#
#
# Sampling 63----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8642857142857142
#
#
# Confusion martix:  [[19.   0. ]
#  [ 5.7 17.3]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.769		1.0		0.866		19.0
# N2-Clean fact		1.0		0.752		0.859		23.0
# accuracy		nan		nan		0.8646		42.0
# macro avg		0.8874		0.876		0.8646		42.0
# weighted avg		0.8974		0.8646		0.8646		42.0
#
#
#
#
# Sampling 64----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7750000000000001
#
#
# Confusion martix:  [[17.    4.  ]
#  [ 5.45 15.55]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7572		0.81		0.782		21.0
# N2-Clean fact		0.7955		0.7385		0.7665		21.0
# accuracy		nan		nan		0.7768		42.0
# macro avg		0.7768		0.7768		0.7768		42.0
# weighted avg		0.7768		0.7768		0.7768		42.0
#
#
#
#
# Sampling 65----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7114285714285714
#
#
# Confusion martix:  [[19.4   3.6 ]
#  [ 8.52 10.48]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6944		0.844		0.76		23.0
# N2-Clean fact		0.7509		0.5531		0.6321		19.0
# accuracy		nan		nan		0.7103		42.0
# macro avg		0.7223		0.6975		0.7		42.0
# weighted avg		0.7224		0.7103		0.7016		42.0
#
#
#
#
# Sampling 66----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8561904761904762
#
#
# Confusion martix:  [[19.    4.  ]
#  [ 2.04 16.96]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8984		0.83		0.8592		23.0
# N2-Clean fact		0.8096		0.888		0.8488		19.0
# accuracy		nan		nan		0.8588		42.0
# macro avg		0.8588		0.8588		0.8588		42.0
# weighted avg		0.8588		0.8588		0.8588		42.0
#
#
#
#
# Sampling 67----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8538095238095239
#
#
# Confusion martix:  [[19.    5.  ]
#  [ 1.14 16.86]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.943		0.79		0.8572		24.0
# N2-Clean fact		0.7686		0.933		0.8458		18.0
# accuracy		nan		nan		0.8558		42.0
# macro avg		0.8558		0.8658		0.8558		42.0
# weighted avg		0.8658		0.8558		0.8558		42.0
#
#
#
#
# Sampling 68----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8657142857142857
#
#
# Confusion martix:  [[17.78  3.22]
#  [ 2.42 18.58]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8812		0.849		0.865		21.0
# N2-Clean fact		0.8529		0.8834		0.8674		21.0
# accuracy		nan		nan		0.8667		42.0
# macro avg		0.8669		0.8667		0.8667		42.0
# weighted avg		0.8669		0.8667		0.8667		42.0
#
#
#
#
# Sampling 69----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8809523809523812
#
#
# Confusion martix:  [[18.  3.]
#  [ 2. 19.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9		0.86		0.88		21.0
# N2-Clean fact		0.86		0.9		0.88		21.0
# accuracy		nan		nan		0.88		42.0
# macro avg		0.88		0.88		0.88		42.0
# weighted avg		0.88		0.88		0.88		42.0
#
#
#
#
# Sampling 70----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8640476190476193
#
#
# Confusion martix:  [[20.    2.  ]
#  [ 3.71 16.29]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8416		0.91		0.8758		22.0
# N2-Clean fact		0.89		0.8145		0.8487		20.0
# accuracy		nan		nan		0.8658		42.0
# macro avg		0.8658		0.8587		0.8658		42.0
# weighted avg		0.8658		0.8658		0.8658		42.0
#
#
#
#
# Sampling 71----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6450000000000002
#
#
# Confusion martix:  [[12.    8.  ]
#  [ 6.91 15.09]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6336		0.6		0.6209		20.0
# N2-Clean fact		0.6518		0.6845		0.6727		22.0
# accuracy		nan		nan		0.6427		42.0
# macro avg		0.6427		0.6418		0.6418		42.0
# weighted avg		0.6427		0.6427		0.6427		42.0
#
#
#
#
# Sampling 72----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9047619047619047
#
#
# Confusion martix:  [[22.  2.]
#  [ 2. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.92		0.92		0.92		24.0
# N2-Clean fact		0.89		0.89		0.89		18.0
# accuracy		nan		nan		0.9		42.0
# macro avg		0.9		0.9		0.9		42.0
# weighted avg		0.9		0.9		0.9		42.0
#
#
#
#
# Sampling 73----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7380952380952382
#
#
# Confusion martix:  [[16. 10.]
#  [ 1. 15.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.94		0.62		0.74		26.0
# N2-Clean fact		0.6		0.94		0.73		16.0
# accuracy		nan		nan		0.74		42.0
# macro avg		0.77		0.78		0.74		42.0
# weighted avg		0.81		0.74		0.74		42.0
#
#
#
#
# Sampling 74----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8388095238095238
#
#
# Confusion martix:  [[17.    2.  ]
#  [ 4.77 18.23]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7793		0.89		0.8346		19.0
# N2-Clean fact		0.8999		0.7916		0.8445		23.0
# accuracy		nan		nan		0.837		42.0
# macro avg		0.8446		0.8446		0.837		42.0
# weighted avg		0.8446		0.837		0.837		42.0
#
#
#
#
# Sampling 75----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7340476190476192
#
#
# Confusion martix:  [[14.    6.  ]
#  [ 5.17 16.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7332		0.7		0.7166		20.0
# N2-Clean fact		0.7383		0.7642		0.7539		22.0
# accuracy		nan		nan		0.7339		42.0
# macro avg		0.7339		0.7339		0.7339		42.0
# weighted avg		0.7339		0.7339		0.7339		42.0
#
#
#
#
# Sampling 76----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8035714285714286
#
#
# Confusion martix:  [[14.    3.  ]
#  [ 5.25 19.75]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.73		0.82		0.775		17.0
# N2-Clean fact		0.8675		0.79		0.825		25.0
# accuracy		nan		nan		0.805		42.0
# macro avg		0.795		0.805		0.8025		42.0
# weighted avg		0.815		0.805		0.805		42.0
#
#
#
#
# Sampling 77----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7619047619047618
#
#
# Confusion martix:  [[19.  6.]
#  [ 4. 13.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.83		0.76		0.79		25.0
# N2-Clean fact		0.68		0.76		0.72		17.0
# accuracy		nan		nan		0.76		42.0
# macro avg		0.76		0.76		0.76		42.0
# weighted avg		0.77		0.76		0.76		42.0
#
#
#
#
# Sampling 78----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9202380952380952
#
#
# Confusion martix:  [[18.94  0.06]
#  [ 3.29 19.71]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.851		0.997		0.9198		19.0
# N2-Clean fact		0.997		0.8584		0.9201		23.0
# accuracy		nan		nan		0.9198		42.0
# macro avg		0.9224		0.923		0.9198		42.0
# weighted avg		0.9324		0.9198		0.9198		42.0
#
#
#
#
# Sampling 79----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9135714285714286
#
#
# Confusion martix:  [[21.32  0.68]
#  [ 2.95 17.05]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8796		0.9694		0.924		22.0
# N2-Clean fact		0.9634		0.8525		0.9045		20.0
# accuracy		nan		nan		0.913		42.0
# macro avg		0.9206		0.9128		0.913		42.0
# weighted avg		0.9206		0.913		0.913		42.0
#
#
#
#
# Sampling 80----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9395238095238096
#
#
# Confusion martix:  [[23.51  0.49]
#  [ 2.05 15.95]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9184		0.9804		0.9492		24.0
# N2-Clean fact		0.9706		0.887		0.9238		18.0
# accuracy		nan		nan		0.9391		42.0
# macro avg		0.9443		0.9292		0.9391		42.0
# weighted avg		0.9443		0.9391		0.9391		42.0
#
#
#
#
# Sampling 81----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.9742857142857144
#
#
# Confusion martix:  [[20.92  0.08]
#  [ 1.   20.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.95		0.996		0.9776		21.0
# N2-Clean fact		0.996		0.95		0.9776		21.0
# accuracy		nan		nan		0.9776		42.0
# macro avg		0.9776		0.9776		0.9776		42.0
# weighted avg		0.9776		0.9776		0.9776		42.0
#
#
#
#
# Sampling 82----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8604761904761905
#
#
# Confusion martix:  [[15.18  2.82]
#  [ 3.04 20.96]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8302		0.8408		0.8346		18.0
# N2-Clean fact		0.8851		0.878		0.8807		24.0
# accuracy		nan		nan		0.8625		42.0
# macro avg		0.8545		0.8546		0.8546		42.0
# weighted avg		0.8628		0.8625		0.8625		42.0
#
#
#
#
# Sampling 83----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8809523809523812
#
#
# Confusion martix:  [[17.  3.]
#  [ 2. 20.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.89		0.85		0.87		20.0
# N2-Clean fact		0.87		0.91		0.89		22.0
# accuracy		nan		nan		0.88		42.0
# macro avg		0.88		0.88		0.88		42.0
# weighted avg		0.88		0.88		0.88		42.0
#
#
#
#
# Sampling 84----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8111904761904762
#
#
# Confusion martix:  [[18.    1.  ]
#  [ 6.93 16.07]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7221		0.95		0.8214		19.0
# N2-Clean fact		0.94		0.7028		0.8021		23.0
# accuracy		nan		nan		0.8114		42.0
# macro avg		0.8314		0.8214		0.8114		42.0
# weighted avg		0.8414		0.8114		0.8114		42.0
#
#
#
#
# Sampling 85----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7628571428571429
#
#
# Confusion martix:  [[20.    3.  ]
#  [ 6.96 12.04]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7412		0.87		0.8008		23.0
# N2-Clean fact		0.8004		0.632		0.71		19.0
# accuracy		nan		nan		0.7624		42.0
# macro avg		0.7708		0.7512		0.7524		42.0
# weighted avg		0.7708		0.7624		0.7596		42.0
#
#
#
#
# Sampling 86----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7361904761904761
#
#
# Confusion martix:  [[14.66  5.34]
#  [ 5.74 16.26]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7196		0.733		0.725		20.0
# N2-Clean fact		0.7557		0.7396		0.7479		22.0
# accuracy		nan		nan		0.7351		42.0
# macro avg		0.7353		0.7351		0.7351		42.0
# weighted avg		0.7365		0.7351		0.7351		42.0
#
#
#
#
# Sampling 87----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8035714285714286
#
#
# Confusion martix:  [[20.    2.  ]
#  [ 6.25 13.75]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7625		0.91		0.8275		22.0
# N2-Clean fact		0.8775		0.6875		0.77		20.0
# accuracy		nan		nan		0.805		42.0
# macro avg		0.815		0.795		0.8025		42.0
# weighted avg		0.815		0.805		0.8025		42.0
#
#
#
#
# Sampling 88----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8457142857142856
#
#
# Confusion martix:  [[16.32  2.68]
#  [ 3.8  19.2 ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8112		0.856		0.8336		19.0
# N2-Clean fact		0.8767		0.8361		0.8543		23.0
# accuracy		nan		nan		0.8464		42.0
# macro avg		0.847		0.847		0.8464		42.0
# weighted avg		0.847		0.8464		0.8464		42.0
#
#
#
#
# Sampling 89----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5952380952380951
#
#
# Confusion martix:  [[11. 12.]
#  [ 5. 14.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.69		0.48		0.56		23.0
# N2-Clean fact		0.54		0.74		0.62		19.0
# accuracy		nan		nan		0.6		42.0
# macro avg		0.61		0.61		0.59		42.0
# weighted avg		0.62		0.6		0.59		42.0
#
#
#
#
# Sampling 90----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8809523809523812
#
#
# Confusion martix:  [[21.  2.]
#  [ 3. 16.]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.88		0.91		0.89		23.0
# N2-Clean fact		0.89		0.84		0.86		19.0
# accuracy		nan		nan		0.88		42.0
# macro avg		0.88		0.88		0.88		42.0
# weighted avg		0.88		0.88		0.88		42.0
#
#
#
#
# Sampling 91----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7523809523809526
#
#
# Confusion martix:  [[11.   1. ]
#  [ 9.4 20.6]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5383		0.92		0.682		12.0
# N2-Clean fact		0.9514		0.6877		0.7969		30.0
# accuracy		nan		nan		0.7531		42.0
# macro avg		0.7471		0.8006		0.7417		42.0
# weighted avg		0.836		0.7531		0.7634		42.0
#
#
#
#
# Sampling 92----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8730952380952381
#
#
# Confusion martix:  [[20.73  4.27]
#  [ 1.06 15.94]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9476		0.8292		0.8834		25.0
# N2-Clean fact		0.7886		0.9364		0.8528		17.0
# accuracy		nan		nan		0.8734		42.0
# macro avg		0.8728		0.8828		0.8728		42.0
# weighted avg		0.8855		0.8734		0.8734		42.0
#
#
#
#
# Sampling 93----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8847619047619049
#
#
# Confusion martix:  [[18.    2.  ]
#  [ 2.84 19.16]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8664		0.9		0.8832		20.0
# N2-Clean fact		0.9029		0.8693		0.8861		22.0
# accuracy		nan		nan		0.8832		42.0
# macro avg		0.8832		0.8832		0.8832		42.0
# weighted avg		0.8832		0.8832		0.8832		42.0
#
#
#
#
# Sampling 94----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7990476190476191
#
#
# Confusion martix:  [[17.    4.  ]
#  [ 4.44 16.56]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7924		0.81		0.8012		21.0
# N2-Clean fact		0.8056		0.788		0.7968		21.0
# accuracy		nan		nan		0.8012		42.0
# macro avg		0.8012		0.8012		0.8012		42.0
# weighted avg		0.8012		0.8012		0.8012		42.0
#
#
#
#
# Sampling 95----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.759047619047619
#
#
# Confusion martix:  [[21.88  3.12]
#  [ 7.   10.  ]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.7588		0.8752		0.8076		25.0
# N2-Clean fact		0.7628		0.59		0.6676		17.0
# accuracy		nan		nan		0.7576		42.0
# macro avg		0.7564		0.7276		0.7376		42.0
# weighted avg		0.7576		0.7576		0.7476		42.0
#
#
#
#
# Sampling 96----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8580952380952382
#
#
# Confusion martix:  [[14.21  2.79]
#  [ 3.17 21.83]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8153		0.8326		0.8249		17.0
# N2-Clean fact		0.8883		0.8732		0.8804		25.0
# accuracy		nan		nan		0.8592		42.0
# macro avg		0.8528		0.8529		0.8528		42.0
# weighted avg		0.8605		0.8592		0.8592		42.0
#
#
#
#
# Sampling 97----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8135714285714286
#
#
# Confusion martix:  [[11.31  2.69]
#  [ 5.14 22.86]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.6906		0.8117		0.7396		14.0
# N2-Clean fact		0.8924		0.8158		0.8534		28.0
# accuracy		nan		nan		0.8134		42.0
# macro avg		0.7928		0.8102		0.7965		42.0
# weighted avg		0.8265		0.8134		0.8157		42.0
#
#
#
#
# Sampling 98----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.913809523809524
#
#
# Confusion martix:  [[20.76  1.24]
#  [ 2.38 17.62]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.8967		0.9392		0.9164		22.0
# N2-Clean fact		0.9356		0.881		0.9038		20.0
# accuracy		nan		nan		0.9133		42.0
# macro avg		0.9164		0.9133		0.9133		42.0
# weighted avg		0.9164		0.9133		0.9133		42.0
#
#
#
#
# Sampling 99----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.931904761904762
#
#
# Confusion martix:  [[17.02  1.98]
#  [ 0.88 22.12]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.9474		0.8912		0.923		19.0
# N2-Clean fact		0.9208		0.9648		0.9428		23.0
# accuracy		nan		nan		0.9328		42.0
# macro avg		0.934		0.9328		0.9328		42.0
# weighted avg		0.934		0.9328		0.9328		42.0
#
#
#
#
# Sampling 100----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7430952380952379
#
#
# Confusion martix:  [[14.    1.  ]
#  [ 9.79 17.21]]
#
#
# Classes		precision		recall		f1-score		support
# N1-Clean fact		0.5888		0.93		0.7242		15.0
# N2-Clean fact		0.9436		0.6378		0.7624		27.0
# accuracy		nan		nan		0.7425		42.0
# macro avg		0.766		0.7842		0.7421		42.0
# weighted avg		0.822		0.7425		0.7477		42.0

# %%
final_ave_ConfusionMatrix=(np.round(np.average(conf_martix_ave_collect,axis=0))).astype(int)
print("Confusion Matrix\n",final_ave_ConfusionMatrix)
# Out:
# Confusion Matrix
#  [[17  4]
#  [ 4 17]]

# %%
class_names = ['1', '2']
fig, ax = plot_confusion_matrix(conf_mat=final_ave_ConfusionMatrix,
                                colorbar=True,
                                #show_absolute=False,
                                #show_normed=True,
                                class_names=class_names)
plt.show()

# %%
final_ave_ReportMatrix=np.round (np.average(report_matrix_ave_collect,axis=0),decimals=3)
print("Report Matrix\n",final_ave_ReportMatrix)
# Out:
# Report Matrix
#  [[ 0.8    0.828  0.807 20.88 ]
#  [ 0.829  0.796  0.806 21.12 ]
#  [   nan    nan  0.809 42.   ]
#  [ 0.814  0.812  0.807 42.   ]
#  [ 0.822  0.809  0.809 42.   ]]

# %% [markdown]
# ## 4.3 Improt preprocessed results (importance)

# %%
path_preprocessed_results="./RF_results_2L/preprocessed_results_sl3_2M_4L_Cross.csv"
preprocessed_results=np.array(pd.read_csv(path_preprocessed_results,header=None))
preprocessed_results.shape
# Out:
# (100, 10304)

# %% [markdown]
# ## 4.4 Compute the important features for each undersampling

# %%
groups=4
top_select=70

# %%
print("preprocessed_results.shape[0]",preprocessed_results.shape,"\n")

group_importance=[]
selected_feature_indices=[]

memebers=int(preprocessed_results.shape[0]/float(groups))
for group_i in np.arange(groups):
    group_importance_i=np.sum(preprocessed_results[group_i*memebers:(group_i+1)*memebers,:],axis=0)
    indices_i=np.argsort(group_importance_i)[::-1][0:top_select]
    
    group_importance.append(group_importance_i)
    selected_feature_indices.append(indices_i)
# Out:
# preprocessed_results.shape[0] (100, 10304)

# %%
for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.draw_with_importance(group_importance[group_i],original_edge_width,original_edge_length,top_select)
# Out:
# The number of group 0
# The number of group 1
# The number of group 2
# The number of group 3

# %%
F.draw_with_importance(np.mean(group_importance,axis=0),original_edge_width,original_edge_length,top_select)

# %% [markdown]
# ## 4.5 Compute the common important features from each undersampling

# %%
interect_indices=F.intersect_2Dlist(selected_feature_indices)
background=np.zeros(original_edge_length*original_edge_width)
background[F.intersect_2Dlist(selected_feature_indices)]=group_importance[0][interect_indices]

# %%
common_feature_catch=[]
for interect_indices_i in interect_indices:
    common_feature_catch.append([int(interect_indices_i/(original_edge_length)),interect_indices_i%(original_edge_length)])

for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.show_one_figure_with_keyfeature(group_importance[group_i],common_feature_catch,original_edge_width,original_edge_length)
    
F.show_one_figure_with_keyfeature(np.average(np.array(group_importance),axis=0),common_feature_catch,original_edge_width,original_edge_length)
# Out:
# The number of group 0
# The number of group 1
# The number of group 2
# The number of group 3

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length))
plt.axis('off')
plt.show()

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length),plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4.6 Show the common important features from each undersampling and comparing with the original key features

# %%
F.show_one_figure_with_keyfeature(Collect_noise_data.sum(axis=0),common_feature_catch,original_edge_width,original_edge_length)

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()
