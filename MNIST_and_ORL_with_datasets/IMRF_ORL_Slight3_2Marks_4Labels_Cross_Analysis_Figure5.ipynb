# %% [markdown]
# # 1. Import libraries

# %%
#----------------------------Reproducible----------------------------------------------------------------------------------------
import numpy as np
import tensorflow as tf
import random as rn
import os

seed=0
os.environ['PYTHONHASHSEED'] = str(seed)

np.random.seed(seed)
rn.seed(seed)
#session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
session_conf =tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

#tf.set_random_seed(seed)
tf.compat.v1.set_random_seed(seed)
#sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)

K.set_session(sess)
#----------------------------Reproducible----------------------------------------------------------------------------------------

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

#--------------------------------------------------------------------------------------------------------------------------------
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Input, Flatten, Activation, Dropout, Layer
from keras.layers.normalization import BatchNormalization
from keras.utils import to_categorical,plot_model
from keras import optimizers,initializers,constraints,regularizers
from keras import backend as K
from keras.callbacks import LambdaCallback,ModelCheckpoint
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn import svm
from sklearn.model_selection import cross_val_score,ShuffleSplit,train_test_split,StratifiedKFold
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.under_sampling import RandomUnderSampler
from skimage import io
from PIL import Image
import scipy.sparse as sparse
import pandas as pd
import random
import h5py
import math
import gc
from functools import reduce
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mlxtend.plotting import plot_confusion_matrix

# %matplotlib inline
matplotlib.style.use('ggplot')

#--------------------------------------------------------------------------------------------------------------------------------
#Import ourslef defined methods
import sys
sys.path.append(r"./Defined")
import Functions as F
# Out:
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# # 2. Parameters

# %%
dataset_path='./data/faces/ORL_Faces/'

original_edge_length=92
original_edge_width=112

black_area=4

number_samples_for_show=30

minority1=30
minority2=70
minority3=40
majority=90
sampling_times=100
seed_range=np.random.randint(100,size=100)#np.arange(0,100,1)
p_n_estimators=2100

# %% [markdown]
# # 3. Import data

# %% [markdown]
# ## 3.1 Loading data

# %%
points = {}

for dirpath, dirnames, filenames in os.walk(dataset_path):
    dirnames.sort()
    filenames.sort()
    for filename in [f for f in filenames if f.endswith(".pgm") and not f[0] == '.']:
        full_path = os.path.join(dirpath, filename)
        filename = full_path.split('/')[-1]
        file_identifier="%s" % (full_path.split('/')[-3])
        #print(file_identifier)
        if file_identifier not in points.keys():
            points[file_identifier] = []
        #image = io.imread(full_path)
        image_=Image.open(full_path).resize((original_edge_length, original_edge_width),Image.ANTIALIAS)
        image=np.asarray(image_)
        points[file_identifier].append(image)

#--------------------------------------------------------------------------------------------------------------------------------
Feature = []
for key in points.keys():
    for image_i in range(len(points[key])):
        Feature.append(np.array(points[key][image_i]))

Features=np.array(Feature)
rn.shuffle(Features)

Features_part1=Features[0:(400-minority1-minority2-minority3)]
Features_part2=Features[(400-minority1-minority2-minority3):(400-minority2-minority3)]
Features_part3=Features[(400-minority2-minority3):(400-minority3)]
Features_part4=Features[(400-minority3):]

Labels=np.r_[np.array([0]*(400-minority1-minority2-minority3)),np.array([1]*minority1),np.array([2]*minority2),np.array([3]*minority3)]

# %% [markdown]
# ## 3.2 Add noise to data

# %%
#--------------------------------------------------------------------------------------------------------------------------------
Collect1_noise_data=[]
for i in np.arange(400-minority1-minority2-minority3):
    Collect1_noise_data_i=np.zeros(Features_part2[1].shape)
    Collect1_noise_data.append(Collect1_noise_data_i)

#--------------------------------------------------------------------------------------------------------------------------------
Collect2_noise_data=[]
for i in np.arange(0,minority1):
    Features_part2_i=Features_part2[i]
    
    noise_data=Features_part2_i
    
    Collect2_noise_data_i=np.zeros(Features_part2[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)

for i in np.arange(0,minority2):
    Features_part3_i=Features_part3[i]
    
    noise_data=Features_part3_i
    
    Collect2_noise_data_i=np.zeros(Features_part3[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):         
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
    
for i in np.arange(0,minority3):
    Features_part4_i=Features_part4[i]
    
    noise_data=Features_part4_i
    
    Collect2_noise_data_i=np.zeros(Features_part4[1].shape)
    
    Up_Down_position=random.randint(-3,3)
    Left_Right_position=random.randint(-3,3)
    #Up_Down_position=0
    #Left_Right_position=0
    
    for m in np.arange(black_area):
        for n in np.arange(black_area):
            noise_position_1=19+m+Up_Down_position
            noise_position_2=19+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1   
            
            noise_position_1=89+m+Up_Down_position
            noise_position_2=29+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
            noise_position_1=69+m+Up_Down_position
            noise_position_2=69+n+Left_Right_position
            
            noise_data[noise_position_1,noise_position_2]=0.1
            Collect2_noise_data_i[noise_position_1,noise_position_2]=0.1
            
    Collect2_noise_data.append(Collect2_noise_data_i)
    
#--------------------------------------------------------------------------------------------------------------------------------
Array_Feature = []
for i in np.arange(Features.shape[0]):
    Array_Feature.append(Features[i].flatten())

#--------------------------------------------------------------------------------------------------------------------------------
Collect_noise_data=np.array(Collect1_noise_data+Collect2_noise_data)
print('Shape of Collect_noise_data',Collect_noise_data.shape)
# Out:
# Shape of Collect_noise_data (400, 112, 92)

# %%
rand_indices = np.random.permutation(400)

Array_Feature_=np.array(Array_Feature)[rand_indices]
Labels_=np.array(Labels)[rand_indices]

# %% [markdown]
# ## 3.3 The number of samples for different classes

# %%
for i in np.arange(4):
    print(i,":",np.sum(Labels_==i))
# Out:
# 0 : 260
# 1 : 30
# 2 : 70
# 3 : 40

# %% [markdown]
# ## 3.4 Do undersampling and generate multiple sample subsets

# %%
Samples_list=[]
Labels_for_Samples_list=[]
for time_i in np.arange(sampling_times):
    seed_i=time_i
    rus=RandomUnderSampler(sampling_strategy={0: majority,1:minority1,2:minority2,3:minority3},random_state=seed_i,replacement=True)
    Samples_,Labels_for_Samples_=rus.fit_sample(Array_Feature_,Labels_)
    Samples_list.append(Samples_)
    Labels_for_Samples_list.append(Labels_for_Samples_)

# %% [markdown]
# ## 3.5 Split training and testing samples

# %%
X_train_list=[]
X_test_list=[]
y_train_list=[]
y_test_list=[]

for time_i in np.arange(sampling_times):
    Samples_list_i_=Samples_list[time_i]
    Labels_for_Samples_i_=Labels_for_Samples_list[time_i]
    rand_indices = np.random.permutation(majority+minority1+minority2+minority3)
    Samples_list_i=Samples_list_i_[rand_indices]
    Labels_for_Samples_i=Labels_for_Samples_i_[rand_indices]
    
    X_train_i,X_test_i, y_train_i, y_test_i =train_test_split(Samples_list_i,Labels_for_Samples_i,test_size=0.3, random_state=seed)

    print('Shape of X_train_i: ' + str(X_train_i.shape))
    print('Shape of y_train_i: ' + str(y_train_i.shape))
    print('Shape of X_test_i: ' + str(X_test_i.shape))
    print('Shape of y_test_i: ' + str(y_test_i.shape))
    
    X_train_list.append(X_train_i)
    X_test_list.append(X_test_i)
    y_train_list.append(y_train_i)
    y_test_list.append(y_test_i)
    
    print("\n======================================================\n\n")
# Out:
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================
#
#
# Shape of X_train_i: (161, 10304)
# Shape of y_train_i: (161,)
# Shape of X_test_i: (69, 10304)
# Shape of y_test_i: (69,)
#
# ======================================================

# %% [markdown]
# ## 3.6 Display training and testing samples

# %%
F.show_data_figures(np.array(X_train_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)
# Out:
# ./Defined/Functions.py:71: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(p_pad,p_w_pad, p_h_pad)

# %%
y_train_list[0][0:number_samples_for_show]
# Out:
# array([2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 3, 2, 0,
#        2, 0, 2, 2, 3, 3, 2, 3])

# %%
F.show_data_figures(np.array(X_train_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([0, 2, 0, 1, 1, 0, 3, 2, 0, 0, 3, 0, 1, 2, 0, 1, 2, 2, 1, 2, 0, 3,
#        0, 0, 0, 3, 1, 3, 0, 3])

# %%
F.show_data_figures(np.array(X_test_list[0])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_test_list[0][0:number_samples_for_show]
# Out:
# array([2, 0, 0, 0, 1, 0, 2, 0, 1, 2, 3, 0, 2, 0, 2, 3, 2, 0, 3, 0, 3, 3,
#        2, 1, 2, 2, 2, 1, 2, 2])

# %%
F.show_data_figures(np.array(X_test_list[1])[0:number_samples_for_show,:],original_edge_width,original_edge_length,columns = 10,p_pad=-2,p_w_pad=0.15, p_h_pad=-1)

# %%
y_train_list[1][0:number_samples_for_show]
# Out:
# array([0, 2, 0, 1, 1, 0, 3, 2, 0, 0, 3, 0, 1, 2, 0, 1, 2, 2, 1, 2, 0, 3,
#        0, 0, 0, 3, 1, 3, 0, 3])

# %% [markdown]
# # 4 Analysis

# %% [markdown]
# ## 4.1 Improt predicated results

# %%
path_predicated_results="./RF_results/predicated_results_sl3_2M_4L_Cross.csv"
predicated_results=pd.read_csv(path_predicated_results, sep='delimiter', header=None)
class_names=["Clean fact","N1-Clean fact","N2-Clean fact","N12-Clean fact"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %% [markdown]
# ## 4.2 Average accuarcy and confusion matrix

# %%
time_i=int(predicated_results.shape[0]/(4*len(seed_range)))
print("The number of samplings: ",time_i)

Acc_train_ave_collect=[]
Acc_test_ave_collect=[]
conf_martix_ave_collect=[]
report_matrix_ave_collect=[]

for time_i in np.arange(time_i):
    print("Sampling "+str(time_i+1)+"----------------------------------------------------------------------------------\n")
    
    Acc_train_list=[]
    Acc_test_list=[]

    conf_martix=[]
    report_matrix=[]

    for pred_i in np.arange(len(seed_range)*time_i,len(seed_range)*(time_i+1)):
    
        Acc_train=np.array(predicated_results)[4*pred_i]
        Acc_test=np.array(predicated_results)[4*pred_i+1]
        p_y_pred=np.array(predicated_results)[4*pred_i+2]
        p_y_test=np.array(predicated_results)[4*pred_i+3]
        
        Acc_train_list.append(Acc_train)
        Acc_test_list.append(Acc_test)
    
        pred_set=np.array(p_y_pred[0].split(",")).astype(float)
        truth_set=np.array(p_y_test[0].split(",")).astype(float)

        conf_martix_i = np.array(confusion_matrix(truth_set, pred_set))
        conf_martix.append(conf_martix_i)

        report = classification_report(truth_set, pred_set)
        report_matrix_i=[]
        report_matrix_i.append(np.array(report.split('\n')[2].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[3].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[4].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[5].split()[1:]).astype(float))
        report_matrix_i.append(np.array(['nan','nan']+report.split('\n')[7].split()[1:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[8].split()[2:]).astype(float))
        report_matrix_i.append(np.array(report.split('\n')[9].split()[2:]).astype(float))

        report_matrix.append(np.array(report_matrix_i))
    
    # Accuarcy---------------------------------------------------------------------------------------------------------
    Acc_train_ave=np.average(np.array(Acc_train_list).astype(float))
    Acc_test_ave=np.average(np.array(Acc_test_list).astype(float))
    print("Acc_train_ave: ",Acc_train_ave)
    print("Acc_test_ave: ",Acc_test_ave)
    print('\n')

    Acc_train_ave_collect.append(Acc_train_ave)
    Acc_test_ave_collect.append(Acc_test_ave)
    
    # Confusion martix---------------------------------------------------------------------------------------------------------
    conf_martix_ave=np.average(conf_martix,axis=0)
    print("Confusion martix: ",conf_martix_ave)
    print('\n')

    conf_martix_ave_collect.append(conf_martix_ave)

    # Report---------------------------------------------------------------------------------------------------------
    report_matrix_ave=np.average(report_matrix,axis=0)
    Title=np.array(['Classes']+report.split('\n')[0].split()).reshape(1,5)
    report_matrix_ave_=np.c_[np.array(class_names+['accuracy','macro avg','weighted avg']),np.round(report_matrix_ave,decimals=4).astype(str)]

    report_matrix_ave_mergetitle=np.r_[np.array(Title),report_matrix_ave_]

    for i in report_matrix_ave_mergetitle:
        print('\t\t'.join(i))
        
    report_matrix_ave_collect.append(report_matrix_ave)
    
    print("\n\n\n")
# Out:
# The number of samplings:  100
# Sampling 1----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.754927536231884
#
#
# Confusion martix:  [[2.007e+01 1.000e+00 2.930e+00 0.000e+00]
#  [2.000e+00 4.000e+00 3.720e+00 2.800e-01]
#  [2.970e+00 1.000e-02 1.902e+01 2.000e+00]
#  [9.800e-01 0.000e+00 1.020e+00 9.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7722		0.8335		0.8024		24.0
# N1-Clean fact		0.7987		0.4		0.5297		10.0
# N2-Clean fact		0.7103		0.7908		0.7548		24.0
# N12-Clean fact		0.8018		0.82		0.8102		11.0
# accuracy		nan		nan		0.7519		69.0
# macro avg		0.7693		0.7109		0.7195		69.0
# weighted avg		0.7608		0.7519		0.7496		69.0
#
#
#
#
# Sampling 2----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5862318840579711
#
#
# Confusion martix:  [[20.    0.04  5.96  0.  ]
#  [ 7.    4.    0.    1.  ]
#  [ 4.55  3.   13.45  3.  ]
#  [ 2.99  0.    1.01  3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5794		0.77		0.6645		26.0
# N1-Clean fact		0.5672		0.33		0.4192		12.0
# N2-Clean fact		0.6599		0.558		0.6038		24.0
# N12-Clean fact		0.43		0.43		0.43		7.0
# accuracy		nan		nan		0.5844		69.0
# macro avg		0.5593		0.5245		0.5245		69.0
# weighted avg		0.5892		0.5844		0.5744		69.0
#
#
#
#
# Sampling 3----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5595652173913043
#
#
# Confusion martix:  [[18.13  3.    2.    0.87]
#  [ 1.8   1.    3.3   1.9 ]
#  [ 5.86  1.66 14.48  4.  ]
#  [ 1.3   0.    4.7   5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6701		0.7552		0.7112		24.0
# N1-Clean fact		0.1802		0.12		0.1434		8.0
# N2-Clean fact		0.5914		0.5592		0.5744		26.0
# N12-Clean fact		0.4269		0.45		0.4346		11.0
# accuracy		nan		nan		0.561		69.0
# macro avg		0.4661		0.4761		0.4661		69.0
# weighted avg		0.5455		0.561		0.5483		69.0
#
#
#
#
# Sampling 4----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6679710144927539
#
#
# Confusion martix:  [[20.    0.    3.    0.  ]
#  [ 3.    5.    2.    0.  ]
#  [ 3.91  1.   15.09  1.  ]
#  [ 5.    0.    4.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6227		0.87		0.7309		23.0
# N1-Clean fact		0.83		0.5		0.62		10.0
# N2-Clean fact		0.6218		0.7145		0.6727		21.0
# N12-Clean fact		0.86		0.4		0.55		15.0
# accuracy		nan		nan		0.6709		69.0
# macro avg		0.74		0.6209		0.6409		69.0
# weighted avg		0.7109		0.6709		0.6518		69.0
#
#
#
#
# Sampling 5----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6702898550724641
#
#
# Confusion martix:  [[20.    0.    3.    1.  ]
#  [ 3.    3.    0.    1.  ]
#  [ 5.05  1.7  17.25  0.  ]
#  [ 2.    3.    3.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.669		0.83		0.7395		24.0
# N1-Clean fact		0.395		0.43		0.409		7.0
# N2-Clean fact		0.7425		0.72		0.7275		24.0
# N12-Clean fact		0.75		0.43		0.55		14.0
# accuracy		nan		nan		0.6725		69.0
# macro avg		0.6355		0.6025		0.6055		69.0
# weighted avg		0.6825		0.6725		0.6625		69.0
#
#
#
#
# Sampling 6----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6224637681159421
#
#
# Confusion martix:  [[19.06  2.    1.94  0.  ]
#  [ 2.    6.    0.02  0.98]
#  [ 7.11  1.   12.89  4.  ]
#  [ 4.64  1.3   1.06  5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5822		0.8324		0.6837		23.0
# N1-Clean fact		0.585		0.67		0.621		9.0
# N2-Clean fact		0.8085		0.5156		0.6271		25.0
# N12-Clean fact		0.5012		0.42		0.4506		12.0
# accuracy		nan		nan		0.6201		69.0
# macro avg		0.6167		0.6095		0.5965		69.0
# weighted avg		0.6499		0.6201		0.6184		69.0
#
#
#
#
# Sampling 7----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6485507246376814
#
#
# Confusion martix:  [[19.09  3.91  5.    0.  ]
#  [ 0.    4.    4.    0.  ]
#  [ 2.34  1.   15.66  0.  ]
#  [ 1.    0.    7.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8505		0.6827		0.7584		28.0
# N1-Clean fact		0.4454		0.5		0.4727		8.0
# N2-Clean fact		0.4932		0.823		0.6198		19.0
# N12-Clean fact		1.0		0.43		0.6		14.0
# accuracy		nan		nan		0.6482		69.0
# macro avg		0.6982		0.6075		0.6084		69.0
# weighted avg		0.7341		0.6482		0.6543		69.0
#
#
#
#
# Sampling 8----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7334782608695654
#
#
# Confusion martix:  [[25.    2.    1.    0.  ]
#  [ 1.02  7.    0.98  0.  ]
#  [ 3.39  1.   15.61  0.  ]
#  [ 1.    0.    8.    3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8214		0.89		0.8555		28.0
# N1-Clean fact		0.7		0.78		0.74		9.0
# N2-Clean fact		0.6126		0.7805		0.6885		20.0
# N12-Clean fact		1.0		0.25		0.4		12.0
# accuracy		nan		nan		0.7324		69.0
# macro avg		0.7861		0.6761		0.6661		69.0
# weighted avg		0.7757		0.7324		0.7124		69.0
#
#
#
#
# Sampling 9----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6081159420289857
#
#
# Confusion martix:  [[18.94  0.    5.06  0.  ]
#  [ 4.61  2.    1.16  0.23]
#  [ 5.    0.03 13.97  5.  ]
#  [ 1.88  0.    4.07  7.05]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6207		0.7876		0.695		24.0
# N1-Clean fact		0.9901		0.25		0.3988		8.0
# N2-Clean fact		0.5738		0.5788		0.5763		24.0
# N12-Clean fact		0.5724		0.544		0.558		13.0
# accuracy		nan		nan		0.6089		69.0
# macro avg		0.6879		0.5401		0.5594		69.0
# weighted avg		0.6387		0.6089		0.5989		69.0
#
#
#
#
# Sampling 10----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6269565217391304
#
#
# Confusion martix:  [[22.37  0.    5.63  2.  ]
#  [ 0.    4.    4.    0.  ]
#  [ 3.11  0.   12.89  4.  ]
#  [ 2.01  0.99  4.    4.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8108		0.7447		0.7762		30.0
# N1-Clean fact		0.802		0.5		0.6205		8.0
# N2-Clean fact		0.4852		0.6445		0.5535		20.0
# N12-Clean fact		0.4		0.36		0.38		11.0
# accuracy		nan		nan		0.6257		69.0
# macro avg		0.6231		0.5626		0.5827		69.0
# weighted avg		0.6516		0.6257		0.632		69.0
#
#
#
#
# Sampling 11----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6956521739130435
#
#
# Confusion martix:  [[22.  0.  0.  0.]
#  [ 2.  7.  2.  0.]
#  [ 9.  2. 14.  1.]
#  [ 2.  0.  3.  5.]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.63		1.0		0.77		22.0
# N1-Clean fact		0.78		0.64		0.7		11.0
# N2-Clean fact		0.74		0.54		0.62		26.0
# N12-Clean fact		0.83		0.5		0.62		10.0
# accuracy		nan		nan		0.7		69.0
# macro avg		0.74		0.67		0.68		69.0
# weighted avg		0.72		0.7		0.68		69.0
#
#
#
#
# Sampling 12----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6366666666666667
#
#
# Confusion martix:  [[19.    1.    1.    0.  ]
#  [ 6.15  3.85  2.    0.  ]
#  [ 2.    0.   16.    0.  ]
#  [ 5.75  0.    7.17  5.08]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5797		0.9		0.7033		21.0
# N1-Clean fact		0.7925		0.318		0.4565		12.0
# N2-Clean fact		0.614		0.89		0.7257		18.0
# N12-Clean fact		1.0		0.284		0.4356		18.0
# accuracy		nan		nan		0.6378		69.0
# macro avg		0.747		0.5986		0.5788		69.0
# weighted avg		0.737		0.6378		0.5986		69.0
#
#
#
#
# Sampling 13----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6842028985507248
#
#
# Confusion martix:  [[23.31  1.    0.69  2.  ]
#  [ 2.78  1.    0.22  3.  ]
#  [ 5.1   0.   17.9   1.  ]
#  [ 0.8   0.    5.2   5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7297		0.8624		0.7896		27.0
# N1-Clean fact		0.5		0.14		0.22		7.0
# N2-Clean fact		0.7466		0.746		0.7448		24.0
# N12-Clean fact		0.45		0.45		0.45		11.0
# accuracy		nan		nan		0.6851		69.0
# macro avg		0.6061		0.5521		0.5521		69.0
# weighted avg		0.6672		0.6851		0.6632		69.0
#
#
#
#
# Sampling 14----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7439130434782606
#
#
# Confusion martix:  [[19.    2.    2.    0.  ]
#  [ 1.    4.    0.    0.  ]
#  [ 6.3   0.37 23.33  3.  ]
#  [ 0.    0.    3.    5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.721		0.83		0.7725		23.0
# N1-Clean fact		0.633		0.8		0.7078		5.0
# N2-Clean fact		0.8233		0.7099		0.7566		33.0
# N12-Clean fact		0.62		0.62		0.62		8.0
# accuracy		nan		nan		0.7433		69.0
# macro avg		0.6996		0.74		0.7181		69.0
# weighted avg		0.7533		0.7433		0.7433		69.0
#
#
#
#
# Sampling 15----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7391304347826086
#
#
# Confusion martix:  [[24.    0.    1.    1.  ]
#  [ 1.99  9.    1.94  0.07]
#  [ 6.    0.   14.    0.  ]
#  [ 3.72  0.    2.28  4.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6758		0.92		0.7758		26.0
# N1-Clean fact		1.0		0.69		0.82		13.0
# N2-Clean fact		0.7312		0.7		0.7156		20.0
# N12-Clean fact		0.7909		0.4		0.5279		10.0
# accuracy		nan		nan		0.74		69.0
# macro avg		0.7986		0.68		0.71		69.0
# weighted avg		0.7693		0.74		0.73		69.0
#
#
#
#
# Sampling 16----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8244927536231882
#
#
# Confusion martix:  [[26.19  1.    0.81  0.  ]
#  [ 0.3   4.7   1.    0.  ]
#  [ 5.    1.   17.    0.  ]
#  [ 1.    0.    2.    9.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.805		0.9357		0.8678		28.0
# N1-Clean fact		0.698		0.782		0.74		6.0
# N2-Clean fact		0.8176		0.74		0.7738		23.0
# N12-Clean fact		1.0		0.75		0.86		12.0
# accuracy		nan		nan		0.8268		69.0
# macro avg		0.8299		0.7999		0.8129		69.0
# weighted avg		0.8368		0.8268		0.8259		69.0
#
#
#
#
# Sampling 17----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7971014492753622
#
#
# Confusion martix:  [[21.   3.   1.   0. ]
#  [ 2.4  5.   2.   0.6]
#  [ 1.   0.  21.   1. ]
#  [ 0.   0.   3.   8. ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.864		0.84		0.852		25.0
# N1-Clean fact		0.62		0.5		0.56		10.0
# N2-Clean fact		0.78		0.91		0.84		23.0
# N12-Clean fact		0.836		0.73		0.776		11.0
# accuracy		nan		nan		0.8		69.0
# macro avg		0.774		0.75		0.754		69.0
# weighted avg		0.794		0.8		0.79		69.0
#
#
#
#
# Sampling 18----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.786231884057971
#
#
# Confusion martix:  [[20.    0.    4.    0.  ]
#  [ 0.    8.    1.    0.  ]
#  [ 4.    0.   16.25  0.75]
#  [ 1.03  0.    3.97 10.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7991		0.83		0.8194		24.0
# N1-Clean fact		1.0		0.89		0.94		9.0
# N2-Clean fact		0.6434		0.7725		0.7054		21.0
# N12-Clean fact		0.9325		0.67		0.7775		15.0
# accuracy		nan		nan		0.785		69.0
# macro avg		0.845		0.7925		0.8125		69.0
# weighted avg		0.8074		0.785		0.7923		69.0
#
#
#
#
# Sampling 19----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6840579710144931
#
#
# Confusion martix:  [[29.    0.    5.    0.  ]
#  [ 4.    5.    1.    0.  ]
#  [ 5.8   0.   10.2   1.  ]
#  [ 1.66  0.    3.34  3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7141		0.85		0.7754		34.0
# N1-Clean fact		1.0		0.5		0.67		10.0
# N2-Clean fact		0.5238		0.602		0.5579		17.0
# N12-Clean fact		0.75		0.38		0.5		8.0
# accuracy		nan		nan		0.684		69.0
# macro avg		0.7453		0.582		0.6268		69.0
# weighted avg		0.7135		0.684		0.674		69.0
#
#
#
#
# Sampling 20----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8115942028985507
#
#
# Confusion martix:  [[29.03  0.    1.19  0.78]
#  [ 0.    4.    2.    0.  ]
#  [ 4.    1.   13.94  0.06]
#  [ 1.89  2.05  0.03  9.03]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8322		0.9409		0.8817		31.0
# N1-Clean fact		0.5665		0.67		0.6175		6.0
# N2-Clean fact		0.8105		0.7364		0.7732		19.0
# N12-Clean fact		0.9167		0.6924		0.7881		13.0
# accuracy		nan		nan		0.8103		69.0
# macro avg		0.7811		0.7597		0.7621		69.0
# weighted avg		0.8197		0.8103		0.81		69.0
#
#
#
#
# Sampling 21----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.753623188405797
#
#
# Confusion martix:  [[25.    0.    1.    0.  ]
#  [ 6.    4.    1.    0.  ]
#  [ 6.    0.   17.    0.  ]
#  [ 1.75  0.    1.25  6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.645		0.96		0.7725		26.0
# N1-Clean fact		1.0		0.36		0.53		11.0
# N2-Clean fact		0.84		0.74		0.785		23.0
# N12-Clean fact		1.0		0.67		0.8		9.0
# accuracy		nan		nan		0.75		69.0
# macro avg		0.87		0.68		0.72		69.0
# weighted avg		0.81		0.75		0.74		69.0
#
#
#
#
# Sampling 22----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5844927536231884
#
#
# Confusion martix:  [[17.33  3.    4.67  0.  ]
#  [ 4.    3.    0.    0.  ]
#  [ 4.96  3.   14.04  1.  ]
#  [ 3.13  0.    4.91  5.96]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5879		0.6932		0.6346		25.0
# N1-Clean fact		0.33		0.43		0.38		7.0
# N2-Clean fact		0.5964		0.6116		0.6026		23.0
# N12-Clean fact		0.8588		0.4272		0.5672		14.0
# accuracy		nan		nan		0.5852		69.0
# macro avg		0.5933		0.5429		0.5429		69.0
# weighted avg		0.6185		0.5852		0.5851		69.0
#
#
#
#
# Sampling 23----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6682608695652178
#
#
# Confusion martix:  [[22.52  0.    1.48  0.  ]
#  [ 3.08  4.    3.92  0.  ]
#  [ 2.13  1.41 16.59  0.87]
#  [ 2.    0.    8.    3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7589		0.9408		0.8375		24.0
# N1-Clean fact		0.7467		0.36		0.4877		11.0
# N2-Clean fact		0.5538		0.7895		0.6514		21.0
# N12-Clean fact		0.7825		0.23		0.3539		13.0
# accuracy		nan		nan		0.6687		69.0
# macro avg		0.7088		0.5811		0.5816		69.0
# weighted avg		0.6981		0.6687		0.6337		69.0
#
#
#
#
# Sampling 24----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8115942028985507
#
#
# Confusion martix:  [[20.  1.  2.  1.]
#  [ 2.  7.  2.  0.]
#  [ 4.  0. 20.  0.]
#  [ 1.  0.  0.  9.]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.74		0.83		0.78		24.0
# N1-Clean fact		0.88		0.64		0.74		11.0
# N2-Clean fact		0.83		0.83		0.83		24.0
# N12-Clean fact		0.9		0.9		0.9		10.0
# accuracy		nan		nan		0.81		69.0
# macro avg		0.84		0.8		0.81		69.0
# weighted avg		0.82		0.81		0.81		69.0
#
#
#
#
# Sampling 25----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7517391304347825
#
#
# Confusion martix:  [[27.    3.    1.    1.  ]
#  [ 0.    4.    2.    2.  ]
#  [ 1.13  2.   12.87  0.  ]
#  [ 5.    0.    0.    8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8161		0.84		0.8287		32.0
# N1-Clean fact		0.44		0.5		0.47		8.0
# N2-Clean fact		0.8087		0.8022		0.8048		16.0
# N12-Clean fact		0.73		0.62		0.67		13.0
# accuracy		nan		nan		0.7487		69.0
# macro avg		0.6987		0.6887		0.6974		69.0
# weighted avg		0.7574		0.7487		0.7487		69.0
#
#
#
#
# Sampling 26----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8310144927536228
#
#
# Confusion martix:  [[25.    0.    1.    0.  ]
#  [ 0.    5.    2.    0.  ]
#  [ 2.67  0.04 19.29  2.  ]
#  [ 2.31  0.    1.64  8.05]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8329		0.96		0.8927		26.0
# N1-Clean fact		0.9932		0.71		0.8276		7.0
# N2-Clean fact		0.8065		0.8016		0.8051		24.0
# N12-Clean fact		0.801		0.6717		0.7302		12.0
# accuracy		nan		nan		0.8327		69.0
# macro avg		0.8599		0.7839		0.8135		69.0
# weighted avg		0.8358		0.8327		0.8275		69.0
#
#
#
#
# Sampling 27----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6773913043478264
#
#
# Confusion martix:  [[21.74  4.    2.26  1.  ]
#  [ 3.18  6.    1.82  0.  ]
#  [ 4.    3.   12.    1.  ]
#  [ 2.    0.    0.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7038		0.7496		0.723		29.0
# N1-Clean fact		0.46		0.55		0.5		11.0
# N2-Clean fact		0.7481		0.6		0.6684		20.0
# N12-Clean fact		0.78		0.78		0.78		9.0
# accuracy		nan		nan		0.6774		69.0
# macro avg		0.6692		0.6674		0.6674		69.0
# weighted avg		0.6866		0.6774		0.6774		69.0
#
#
#
#
# Sampling 28----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.803478260869565
#
#
# Confusion martix:  [[26.5   0.    2.5   1.  ]
#  [ 4.    7.    2.    0.  ]
#  [ 2.05  0.   11.94  1.01]
#  [ 1.    0.    0.   10.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7885		0.885		0.834		30.0
# N1-Clean fact		1.0		0.54		0.7		13.0
# N2-Clean fact		0.7288		0.7958		0.7576		15.0
# N12-Clean fact		0.8304		0.91		0.8696		11.0
# accuracy		nan		nan		0.8041		69.0
# macro avg		0.8343		0.7838		0.7938		69.0
# weighted avg		0.8241		0.8041		0.7991		69.0
#
#
#
#
# Sampling 29----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.796231884057971
#
#
# Confusion martix:  [[22.    0.    0.    0.  ]
#  [ 2.    7.    0.    0.  ]
#  [ 4.12  0.   19.88  2.  ]
#  [ 3.38  0.89  1.67  6.06]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7		1.0		0.8201		22.0
# N1-Clean fact		0.8932		0.78		0.8266		9.0
# N2-Clean fact		0.9221		0.7652		0.8344		26.0
# N12-Clean fact		0.7518		0.5048		0.6042		12.0
# accuracy		nan		nan		0.7982		69.0
# macro avg		0.8156		0.76		0.7711		69.0
# weighted avg		0.8141		0.7982		0.79		69.0
#
#
#
#
# Sampling 30----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7376811594202897
#
#
# Confusion martix:  [[26.    0.    1.    0.  ]
#  [ 3.09  4.    2.02  0.89]
#  [ 6.08  1.02 11.9   0.  ]
#  [ 3.    0.    1.    9.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.682		0.96		0.7983		27.0
# N1-Clean fact		0.7977		0.4		0.5294		10.0
# N2-Clean fact		0.7439		0.625		0.6811		19.0
# N12-Clean fact		0.911		0.69		0.7844		13.0
# accuracy		nan		nan		0.7335		69.0
# macro avg		0.7863		0.669		0.6997		69.0
# weighted avg		0.7604		0.7335		0.7235		69.0
#
#
#
#
# Sampling 31----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7940579710144928
#
#
# Confusion martix:  [[23.11  0.    5.    0.89]
#  [ 0.    5.    1.    0.  ]
#  [ 2.26  0.06 20.68  1.  ]
#  [ 3.    0.    1.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8133		0.7944		0.807		29.0
# N1-Clean fact		0.9898		0.83		0.9052		6.0
# N2-Clean fact		0.7468		0.8641		0.8005		24.0
# N12-Clean fact		0.7621		0.6		0.6744		10.0
# accuracy		nan		nan		0.7954		69.0
# macro avg		0.8281		0.7743		0.7969		69.0
# weighted avg		0.7984		0.7954		0.7954		69.0
#
#
#
#
# Sampling 32----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6668115942028987
#
#
# Confusion martix:  [[23.    0.    1.    2.  ]
#  [ 3.58  2.    0.66  2.76]
#  [ 5.    2.   15.99  1.01]
#  [ 2.    0.    2.98  5.02]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6884		0.88		0.7741		26.0
# N1-Clean fact		0.5		0.22		0.31		9.0
# N2-Clean fact		0.7775		0.6695		0.72		24.0
# N12-Clean fact		0.4689		0.502		0.485		10.0
# accuracy		nan		nan		0.67		69.0
# macro avg		0.6078		0.5703		0.5703		69.0
# weighted avg		0.6596		0.67		0.6502		69.0
#
#
#
#
# Sampling 33----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6978260869565218
#
#
# Confusion martix:  [[25.15  2.    3.85  0.  ]
#  [ 2.73  2.    1.27  0.  ]
#  [ 2.    0.   14.    2.  ]
#  [ 3.79  0.    3.21  7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.749		0.8137		0.7778		31.0
# N1-Clean fact		0.5		0.33		0.4		6.0
# N2-Clean fact		0.6301		0.78		0.6941		18.0
# N12-Clean fact		0.78		0.5		0.61		14.0
# accuracy		nan		nan		0.7007		69.0
# macro avg		0.6615		0.6023		0.6215		69.0
# weighted avg		0.7015		0.7007		0.6907		69.0
#
#
#
#
# Sampling 34----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6681159420289857
#
#
# Confusion martix:  [[23.02  2.    0.98  1.  ]
#  [ 4.    2.    1.    0.  ]
#  [ 3.92  2.   14.08  1.  ]
#  [ 4.    0.    3.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6618		0.8508		0.7423		27.0
# N1-Clean fact		0.33		0.29		0.31		7.0
# N2-Clean fact		0.738		0.6691		0.701		21.0
# N12-Clean fact		0.78		0.5		0.61		14.0
# accuracy		nan		nan		0.6685		69.0
# macro avg		0.6261		0.5774		0.591		69.0
# weighted avg		0.6723		0.6685		0.6585		69.0
#
#
#
#
# Sampling 35----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6650724637681162
#
#
# Confusion martix:  [[2.000e+01 7.000e-02 1.920e+00 1.000e-02]
#  [2.000e+00 6.000e+00 2.000e+00 0.000e+00]
#  [4.000e+00 0.000e+00 1.589e+01 1.100e-01]
#  [7.470e+00 0.000e+00 5.530e+00 4.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5986		0.91		0.7213		22.0
# N1-Clean fact		0.9902		0.6		0.7472		10.0
# N2-Clean fact		0.6305		0.7945		0.7034		20.0
# N12-Clean fact		0.976		0.24		0.3776		17.0
# accuracy		nan		nan		0.6678		69.0
# macro avg		0.7995		0.6378		0.6382		69.0
# weighted avg		0.7559		0.6678		0.6372		69.0
#
#
#
#
# Sampling 36----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7830434782608695
#
#
# Confusion martix:  [[24.99  0.    1.01  0.  ]
#  [ 4.02  5.    2.99  0.99]
#  [ 2.96  0.   13.04  1.  ]
#  [ 1.    0.    1.   11.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7603		0.9596		0.8498		26.0
# N1-Clean fact		1.0		0.38		0.56		13.0
# N2-Clean fact		0.7208		0.7624		0.7416		17.0
# N12-Clean fact		0.8507		0.85		0.8503		13.0
# accuracy		nan		nan		0.7807		69.0
# macro avg		0.8306		0.7403		0.7503		69.0
# weighted avg		0.8104		0.7807		0.7702		69.0
#
#
#
#
# Sampling 37----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6447826086956523
#
#
# Confusion martix:  [[23.79  2.    1.54  0.67]
#  [ 4.    2.    2.    0.  ]
#  [ 8.    0.   12.    2.  ]
#  [ 2.26  0.97  1.07  6.7 ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6252		0.8508		0.7232		28.0
# N1-Clean fact		0.403		0.25		0.3106		8.0
# N2-Clean fact		0.7256		0.55		0.6234		22.0
# N12-Clean fact		0.7172		0.6128		0.6589		11.0
# accuracy		nan		nan		0.6448		69.0
# macro avg		0.6176		0.5619		0.5758		69.0
# weighted avg		0.6445		0.6448		0.632		69.0
#
#
#
#
# Sampling 38----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.696231884057971
#
#
# Confusion martix:  [[25.    0.    1.    0.  ]
#  [ 2.    6.    1.9   0.1 ]
#  [11.96  0.   11.04  0.  ]
#  [ 2.    0.    2.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6104		0.96		0.7504		26.0
# N1-Clean fact		1.0		0.6		0.75		10.0
# N2-Clean fact		0.6948		0.4816		0.5636		23.0
# N12-Clean fact		0.986		0.6		0.746		10.0
# accuracy		nan		nan		0.7004		69.0
# macro avg		0.8184		0.6604		0.7004		69.0
# weighted avg		0.7494		0.7004		0.6904		69.0
#
#
#
#
# Sampling 39----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6731884057971018
#
#
# Confusion martix:  [[2.003e+01 2.350e+00 2.620e+00 0.000e+00]
#  [9.900e-01 8.000e+00 1.000e-02 0.000e+00]
#  [2.580e+00 0.000e+00 1.542e+01 2.000e+00]
#  [2.670e+00 0.000e+00 9.330e+00 3.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7631		0.8012		0.7803		25.0
# N1-Clean fact		0.7755		0.89		0.826		9.0
# N2-Clean fact		0.5643		0.771		0.6518		20.0
# N12-Clean fact		0.6		0.2		0.3		15.0
# accuracy		nan		nan		0.6739		69.0
# macro avg		0.6746		0.6645		0.641		69.0
# weighted avg		0.6708		0.6739		0.6445		69.0
#
#
#
#
# Sampling 40----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6872463768115944
#
#
# Confusion martix:  [[26.18  0.59  6.81  1.42]
#  [ 0.    2.    0.    0.  ]
#  [ 3.68  2.08 16.24  0.  ]
#  [ 1.    2.08  3.92  3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8496		0.7454		0.7968		35.0
# N1-Clean fact		0.3		1.0		0.4582		2.0
# N2-Clean fact		0.6033		0.7396		0.6634		22.0
# N12-Clean fact		0.687		0.3		0.4174		10.0
# accuracy		nan		nan		0.688		69.0
# macro avg		0.6072		0.6942		0.5838		69.0
# weighted avg		0.7322		0.688		0.6876		69.0
#
#
#
#
# Sampling 41----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.782608695652174
#
#
# Confusion martix:  [[26.  0.  3.  2.]
#  [ 2.  6.  1.  0.]
#  [ 1.  0. 19.  0.]
#  [ 2.  0.  4.  3.]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.84		0.84		0.84		31.0
# N1-Clean fact		1.0		0.67		0.8		9.0
# N2-Clean fact		0.7		0.95		0.81		20.0
# N12-Clean fact		0.6		0.33		0.43		9.0
# accuracy		nan		nan		0.78		69.0
# macro avg		0.79		0.7		0.72		69.0
# weighted avg		0.79		0.78		0.77		69.0
#
#
#
#
# Sampling 42----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.755072463768116
#
#
# Confusion martix:  [[28.    1.    1.    0.  ]
#  [ 3.97  2.    0.03  0.  ]
#  [ 3.9   2.   15.1   0.  ]
#  [ 1.37  1.    2.63  7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7552		0.93		0.8339		30.0
# N1-Clean fact		0.33		0.33		0.33		6.0
# N2-Clean fact		0.8046		0.7169		0.7598		21.0
# N12-Clean fact		1.0		0.58		0.74		12.0
# accuracy		nan		nan		0.7539		69.0
# macro avg		0.7232		0.641		0.664		69.0
# weighted avg		0.7747		0.7539		0.7491		69.0
#
#
#
#
# Sampling 43----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7262318840579709
#
#
# Confusion martix:  [[24.    0.    8.    3.  ]
#  [ 0.    6.    0.    0.  ]
#  [ 0.99  2.   13.1   1.91]
#  [ 0.14  0.    2.85  7.01]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.9548		0.69		0.7987		35.0
# N1-Clean fact		0.75		1.0		0.86		6.0
# N2-Clean fact		0.5461		0.726		0.6249		18.0
# N12-Clean fact		0.5858		0.701		0.6433		10.0
# accuracy		nan		nan		0.7222		69.0
# macro avg		0.7116		0.7812		0.7312		69.0
# weighted avg		0.7798		0.7222		0.7318		69.0
#
#
#
#
# Sampling 44----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.696086956521739
#
#
# Confusion martix:  [[23.    1.    4.    0.  ]
#  [ 0.    3.    3.62  0.38]
#  [ 5.97  1.   16.03  0.  ]
#  [ 1.    0.    4.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7708		0.82		0.7905		28.0
# N1-Clean fact		0.6		0.43		0.5		7.0
# N2-Clean fact		0.578		0.7013		0.6345		23.0
# N12-Clean fact		0.9468		0.55		0.6948		11.0
# accuracy		nan		nan		0.7004		69.0
# macro avg		0.719		0.6204		0.6565		69.0
# weighted avg		0.7167		0.7004		0.6905		69.0
#
#
#
#
# Sampling 45----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6559420289855075
#
#
# Confusion martix:  [[22.    1.04  5.35  0.61]
#  [ 0.08  4.    2.92  1.  ]
#  [ 5.74  0.   14.26  2.  ]
#  [ 0.    0.    5.    5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7941		0.7573		0.7752		29.0
# N1-Clean fact		0.7948		0.5		0.618		8.0
# N2-Clean fact		0.5156		0.6488		0.5754		22.0
# N12-Clean fact		0.5834		0.5		0.5417		10.0
# accuracy		nan		nan		0.6566		69.0
# macro avg		0.6716		0.6021		0.6237		69.0
# weighted avg		0.6737		0.6566		0.6575		69.0
#
#
#
#
# Sampling 46----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6811594202898554
#
#
# Confusion martix:  [[22.    0.    4.    0.  ]
#  [ 1.14  3.    5.    0.86]
#  [ 2.    0.   16.    2.  ]
#  [ 5.    1.    1.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7272		0.85		0.7872		26.0
# N1-Clean fact		0.75		0.3		0.43		10.0
# N2-Clean fact		0.62		0.8		0.7		20.0
# N12-Clean fact		0.6812		0.46		0.5528		13.0
# accuracy		nan		nan		0.68		69.0
# macro avg		0.6928		0.6		0.6114		69.0
# weighted avg		0.6914		0.68		0.66		69.0
#
#
#
#
# Sampling 47----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6182608695652174
#
#
# Confusion martix:  [[1.821e+01 1.000e-02 1.730e+00 5.000e-02]
#  [4.000e+00 3.000e+00 2.000e+00 1.000e+00]
#  [9.000e+00 4.500e-01 1.500e+01 5.500e-01]
#  [2.160e+00 0.000e+00 5.390e+00 6.450e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5489		0.9105		0.6826		20.0
# N1-Clean fact		0.885		0.3		0.4462		10.0
# N2-Clean fact		0.6197		0.6		0.6109		25.0
# N12-Clean fact		0.8051		0.4615		0.5874		14.0
# accuracy		nan		nan		0.6177		69.0
# macro avg		0.7144		0.5677		0.5811		69.0
# weighted avg		0.675		0.6177		0.6011		69.0
#
#
#
#
# Sampling 48----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7246376811594202
#
#
# Confusion martix:  [[22.    2.    3.    2.  ]
#  [ 2.    5.    3.    0.  ]
#  [ 4.76  1.   19.    0.24]
#  [ 0.    0.    1.    4.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7672		0.76		0.7624		29.0
# N1-Clean fact		0.62		0.5		0.56		10.0
# N2-Clean fact		0.73		0.76		0.75		25.0
# N12-Clean fact		0.646		0.8		0.7156		5.0
# accuracy		nan		nan		0.72		69.0
# macro avg		0.6952		0.7		0.6952		69.0
# weighted avg		0.7224		0.72		0.72		69.0
#
#
#
#
# Sampling 49----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7960869565217391
#
#
# Confusion martix:  [[25.99  1.01  4.    0.  ]
#  [ 1.    5.    2.71  0.29]
#  [ 3.01  0.   16.94  1.05]
#  [ 1.    0.    0.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8396		0.8397		0.8397		31.0
# N1-Clean fact		0.8288		0.56		0.6696		9.0
# N2-Clean fact		0.7181		0.807		0.761		21.0
# N12-Clean fact		0.846		0.88		0.8596		8.0
# accuracy		nan		nan		0.7985		69.0
# macro avg		0.8057		0.7693		0.7785		69.0
# weighted avg		0.7993		0.7985		0.7959		69.0
#
#
#
#
# Sampling 50----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7136231884057972
#
#
# Confusion martix:  [[19.24  2.4   4.36  0.  ]
#  [ 2.51  4.    2.49  0.  ]
#  [ 2.03  1.   19.    2.97]
#  [ 1.44  0.    0.56  7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.763		0.7396		0.7514		26.0
# N1-Clean fact		0.542		0.44		0.488		9.0
# N2-Clean fact		0.7187		0.76		0.7405		25.0
# N12-Clean fact		0.7028		0.78		0.7412		9.0
# accuracy		nan		nan		0.7132		69.0
# macro avg		0.6801		0.6824		0.6784		69.0
# weighted avg		0.7111		0.7132		0.7111		69.0
#
#
#
#
# Sampling 51----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.657826086956522
#
#
# Confusion martix:  [[24.15  2.    2.85  2.  ]
#  [ 1.    6.    1.    0.  ]
#  [11.81  0.    9.24  1.95]
#  [ 1.    0.    0.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6353		0.776		0.7034		31.0
# N1-Clean fact		0.75		0.75		0.75		8.0
# N2-Clean fact		0.7038		0.3996		0.5116		23.0
# N12-Clean fact		0.6083		0.86		0.712		7.0
# accuracy		nan		nan		0.6585		69.0
# macro avg		0.6759		0.6939		0.666		69.0
# weighted avg		0.6702		0.6585		0.6463		69.0
#
#
#
#
# Sampling 52----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.753623188405797
#
#
# Confusion martix:  [[24.    0.    2.    1.  ]
#  [ 3.    5.    2.    0.  ]
#  [ 1.    0.   16.    1.  ]
#  [ 1.34  1.    4.66  7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8198		0.89		0.8532		27.0
# N1-Clean fact		0.83		0.5		0.62		10.0
# N2-Clean fact		0.6502		0.89		0.7468		18.0
# N12-Clean fact		0.78		0.5		0.61		14.0
# accuracy		nan		nan		0.75		69.0
# macro avg		0.77		0.69		0.71		69.0
# weighted avg		0.77		0.75		0.74		69.0
#
#
#
#
# Sampling 53----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7168115942028987
#
#
# Confusion martix:  [[24.84  0.29  3.87  1.  ]
#  [ 3.    4.    1.    0.  ]
#  [ 5.36  0.   14.64  0.  ]
#  [ 2.98  0.    2.04  5.98]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6892		0.8258		0.7532		30.0
# N1-Clean fact		0.942		0.5		0.6555		8.0
# N2-Clean fact		0.6823		0.732		0.7028		20.0
# N12-Clean fact		0.8594		0.548		0.6684		11.0
# accuracy		nan		nan		0.7168		69.0
# macro avg		0.7922		0.6488		0.6918		69.0
# weighted avg		0.7417		0.7168		0.7119		69.0
#
#
#
#
# Sampling 54----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7365217391304347
#
#
# Confusion martix:  [[18.82  0.    5.18  1.  ]
#  [ 5.    8.    2.    0.  ]
#  [ 1.    0.   16.    1.  ]
#  [ 2.16  0.    0.84  8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.695		0.7528		0.7244		25.0
# N1-Clean fact		1.0		0.53		0.7		15.0
# N2-Clean fact		0.6698		0.89		0.76		18.0
# N12-Clean fact		0.8		0.73		0.76		11.0
# accuracy		nan		nan		0.7368		69.0
# macro avg		0.7882		0.7282		0.7382		69.0
# weighted avg		0.7682		0.7368		0.7368		69.0
#
#
#
#
# Sampling 55----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7408695652173912
#
#
# Confusion martix:  [[23.    0.    2.    0.  ]
#  [ 3.    4.    0.    2.  ]
#  [ 5.    1.   19.12  0.88]
#  [ 1.    0.    3.    5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.72		0.92		0.81		25.0
# N1-Clean fact		0.8		0.44		0.57		9.0
# N2-Clean fact		0.7912		0.7348		0.7624		26.0
# N12-Clean fact		0.6308		0.56		0.5948		9.0
# accuracy		nan		nan		0.7412		69.0
# macro avg		0.7336		0.6612		0.6824		69.0
# weighted avg		0.7424		0.7412		0.7312		69.0
#
#
#
#
# Sampling 56----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7362318840579709
#
#
# Confusion martix:  [[19.8  0.   1.2  0. ]
#  [ 4.   4.   2.   1. ]
#  [ 6.   0.  19.   0. ]
#  [ 0.   0.   4.   8. ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.668		0.94		0.776		21.0
# N1-Clean fact		1.0		0.36		0.53		11.0
# N2-Clean fact		0.724		0.76		0.746		25.0
# N12-Clean fact		0.89		0.67		0.76		12.0
# accuracy		nan		nan		0.736		69.0
# macro avg		0.818		0.686		0.708		69.0
# weighted avg		0.778		0.736		0.726		69.0
#
#
#
#
# Sampling 57----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6481159420289857
#
#
# Confusion martix:  [[21.    1.    3.    1.  ]
#  [ 2.    7.    2.    0.  ]
#  [ 6.    0.    7.    3.  ]
#  [ 3.    0.    3.28  9.72]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.66		0.81		0.72		26.0
# N1-Clean fact		0.88		0.64		0.74		11.0
# N2-Clean fact		0.4616		0.44		0.4472		16.0
# N12-Clean fact		0.7044		0.6032		0.656		16.0
# accuracy		nan		nan		0.6472		69.0
# macro avg		0.6772		0.6244		0.6372		69.0
# weighted avg		0.6572		0.6472		0.6472		69.0
#
#
#
#
# Sampling 58----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6584057971014495
#
#
# Confusion martix:  [[20.97  1.    6.03  0.  ]
#  [ 3.    3.    1.    0.  ]
#  [ 6.52  0.   13.46  1.02]
#  [ 3.62  1.    0.38  8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6169		0.7488		0.678		28.0
# N1-Clean fact		0.6		0.43		0.5		7.0
# N2-Clean fact		0.6454		0.6415		0.6405		21.0
# N12-Clean fact		0.8882		0.62		0.7294		13.0
# accuracy		nan		nan		0.6571		69.0
# macro avg		0.6841		0.6059		0.6343		69.0
# weighted avg		0.6753		0.6571		0.6559		69.0
#
#
#
#
# Sampling 59----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7236231884057972
#
#
# Confusion martix:  [[21.46  0.    2.54  0.  ]
#  [ 2.    3.    4.    1.  ]
#  [ 5.    0.   19.47  0.53]
#  [ 3.    0.    1.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6846		0.8984		0.7727		24.0
# N1-Clean fact		1.0		0.3		0.46		10.0
# N2-Clean fact		0.7185		0.7788		0.7472		25.0
# N12-Clean fact		0.8035		0.6		0.6888		10.0
# accuracy		nan		nan		0.7213		69.0
# macro avg		0.7993		0.6393		0.6671		69.0
# weighted avg		0.7581		0.7213		0.7065		69.0
#
#
#
#
# Sampling 60----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7326086956521738
#
#
# Confusion martix:  [[2.300e+01 0.000e+00 3.000e+00 0.000e+00]
#  [1.990e+00 6.000e+00 1.000e-02 1.000e+00]
#  [7.450e+00 1.000e+00 1.455e+01 1.000e+00]
#  [1.000e+00 0.000e+00 2.000e+00 7.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6912		0.88		0.7757		26.0
# N1-Clean fact		0.86		0.67		0.75		9.0
# N2-Clean fact		0.7451		0.6041		0.6664		24.0
# N12-Clean fact		0.78		0.7		0.74		10.0
# accuracy		nan		nan		0.7289		69.0
# macro avg		0.7655		0.7155		0.7355		69.0
# weighted avg		0.7454		0.7289		0.7289		69.0
#
#
#
#
# Sampling 61----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6523188405797103
#
#
# Confusion martix:  [[1.788e+01 0.000e+00 6.990e+00 1.130e+00]
#  [4.000e+00 6.000e+00 1.000e+00 0.000e+00]
#  [2.870e+00 1.000e+00 1.413e+01 1.000e+00]
#  [3.000e-02 1.000e-02 5.960e+00 7.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7218		0.6852		0.7071		26.0
# N1-Clean fact		0.8589		0.55		0.6696		11.0
# N2-Clean fact		0.5036		0.7465		0.6031		19.0
# N12-Clean fact		0.7696		0.54		0.6361		13.0
# accuracy		nan		nan		0.6514		69.0
# macro avg		0.7098		0.6301		0.65		69.0
# weighted avg		0.69		0.6514		0.6586		69.0
#
#
#
#
# Sampling 62----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7768115942028985
#
#
# Confusion martix:  [[26.    0.    1.    1.  ]
#  [ 0.    8.    2.    1.  ]
#  [ 2.21  1.   14.6   0.19]
#  [ 4.    0.    3.    5.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8058		0.93		0.8658		28.0
# N1-Clean fact		0.89		0.73		0.8		11.0
# N2-Clean fact		0.706		0.81		0.758		18.0
# N12-Clean fact		0.6929		0.42		0.5243		12.0
# accuracy		nan		nan		0.776		69.0
# macro avg		0.7741		0.722		0.736		69.0
# weighted avg		0.7741		0.776		0.766		69.0
#
#
#
#
# Sampling 63----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6227536231884059
#
#
# Confusion martix:  [[19.69  2.46  2.83  0.02]
#  [ 1.09  4.    1.02  0.89]
#  [ 4.    2.   13.    2.  ]
#  [ 1.    0.16  8.56  6.28]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7642		0.7876		0.7742		25.0
# N1-Clean fact		0.465		0.57		0.5114		7.0
# N2-Clean fact		0.5121		0.62		0.5605		21.0
# N12-Clean fact		0.6858		0.3968		0.4972		16.0
# accuracy		nan		nan		0.6224		69.0
# macro avg		0.606		0.5911		0.5869		69.0
# weighted avg		0.6406		0.6224		0.6208		69.0
#
#
#
#
# Sampling 64----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7391304347826086
#
#
# Confusion martix:  [[24.    1.    6.    0.  ]
#  [ 3.68  3.    0.32  0.  ]
#  [ 3.    0.   16.    0.  ]
#  [ 2.84  0.    1.16  8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7196		0.77		0.7448		31.0
# N1-Clean fact		0.75		0.43		0.55		7.0
# N2-Clean fact		0.6858		0.84		0.752		19.0
# N12-Clean fact		1.0		0.67		0.8		12.0
# accuracy		nan		nan		0.74		69.0
# macro avg		0.7898		0.68		0.71		69.0
# weighted avg		0.7602		0.74		0.74		69.0
#
#
#
#
# Sampling 65----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7531884057971012
#
#
# Confusion martix:  [[25.97  2.    2.03  0.  ]
#  [ 0.    2.    0.    0.  ]
#  [ 3.    1.   18.    0.  ]
#  [ 4.    1.    4.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7897		0.8688		0.8294		30.0
# N1-Clean fact		0.33		1.0		0.5		2.0
# N2-Clean fact		0.7491		0.82		0.7797		22.0
# N12-Clean fact		1.0		0.4		0.57		15.0
# accuracy		nan		nan		0.7497		69.0
# macro avg		0.7197		0.7697		0.6697		69.0
# weighted avg		0.8097		0.7497		0.7494		69.0
#
#
#
#
# Sampling 66----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6589855072463771
#
#
# Confusion martix:  [[21.45  1.    2.67  0.88]
#  [ 3.14  7.    1.86  0.  ]
#  [ 3.15  0.   13.83  4.02]
#  [ 1.29  0.85  4.67  3.19]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7386		0.8271		0.7795		26.0
# N1-Clean fact		0.795		0.58		0.6745		12.0
# N2-Clean fact		0.6025		0.6615		0.6286		21.0
# N12-Clean fact		0.3967		0.319		0.3493		10.0
# accuracy		nan		nan		0.6599		69.0
# macro avg		0.6321		0.5966		0.6085		69.0
# weighted avg		0.6572		0.6599		0.6535		69.0
#
#
#
#
# Sampling 67----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.8253623188405794
#
#
# Confusion martix:  [[27.95  1.05  1.09  0.91]
#  [ 2.    6.    1.    0.  ]
#  [ 3.    1.   13.    0.  ]
#  [ 1.    0.    1.   10.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.82		0.8985		0.859		31.0
# N1-Clean fact		0.746		0.67		0.708		9.0
# N2-Clean fact		0.8055		0.76		0.7873		17.0
# N12-Clean fact		0.9181		0.83		0.8736		12.0
# accuracy		nan		nan		0.829		69.0
# macro avg		0.8199		0.7895		0.809		69.0
# weighted avg		0.829		0.829		0.8204		69.0
#
#
#
#
# Sampling 68----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6657971014492756
#
#
# Confusion martix:  [[19.    1.    4.    0.  ]
#  [ 1.    5.    3.    0.  ]
#  [ 5.    1.   14.    1.  ]
#  [ 3.04  0.    4.02  7.94]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6792		0.79		0.7296		24.0
# N1-Clean fact		0.71		0.56		0.63		9.0
# N2-Clean fact		0.5596		0.67		0.6098		21.0
# N12-Clean fact		0.8894		0.5264		0.6664		15.0
# accuracy		nan		nan		0.6688		69.0
# macro avg		0.7094		0.6388		0.6588		69.0
# weighted avg		0.6894		0.6688		0.6688		69.0
#
#
#
#
# Sampling 69----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.651594202898551
#
#
# Confusion martix:  [[20.    2.    4.    2.  ]
#  [ 0.    7.    0.    0.  ]
#  [ 6.06  0.02 12.92  1.  ]
#  [ 1.98  0.02  6.96  5.04]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7094		0.71		0.7098		28.0
# N1-Clean fact		0.7768		1.0		0.8776		7.0
# N2-Clean fact		0.5394		0.646		0.5882		20.0
# N12-Clean fact		0.6216		0.3628		0.4526		14.0
# accuracy		nan		nan		0.6498		69.0
# macro avg		0.6596		0.68		0.6596		69.0
# weighted avg		0.65		0.6498		0.64		69.0
#
#
#
#
# Sampling 70----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6666666666666669
#
#
# Confusion martix:  [[22.  1.  4.  0.]
#  [ 5.  4.  3.  0.]
#  [ 0.  0. 13.  0.]
#  [ 1.  0.  9.  7.]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.79		0.81		0.8		27.0
# N1-Clean fact		0.8		0.33		0.47		12.0
# N2-Clean fact		0.45		1.0		0.62		13.0
# N12-Clean fact		1.0		0.41		0.58		17.0
# accuracy		nan		nan		0.67		69.0
# macro avg		0.76		0.64		0.62		69.0
# weighted avg		0.78		0.67		0.66		69.0
#
#
#
#
# Sampling 71----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7952173913043478
#
#
# Confusion martix:  [[2.489e+01 9.000e-01 2.110e+00 1.000e-01]
#  [1.000e+00 4.000e+00 1.000e+00 0.000e+00]
#  [2.000e+00 0.000e+00 1.898e+01 2.000e-02]
#  [2.000e+00 0.000e+00 5.000e+00 7.000e+00]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8299		0.8866		0.8578		28.0
# N1-Clean fact		0.82		0.67		0.737		6.0
# N2-Clean fact		0.6976		0.8991		0.7883		21.0
# N12-Clean fact		0.9858		0.5		0.6664		14.0
# accuracy		nan		nan		0.7976		69.0
# macro avg		0.8313		0.7387		0.7596		69.0
# weighted avg		0.8185		0.7976		0.7885		69.0
#
#
#
#
# Sampling 72----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7056521739130437
#
#
# Confusion martix:  [[23.69  0.    5.31  1.  ]
#  [ 1.    5.    1.    0.  ]
#  [ 6.    1.   12.    0.  ]
#  [ 2.    0.    3.    8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7269		0.7907		0.7538		30.0
# N1-Clean fact		0.83		0.71		0.77		7.0
# N2-Clean fact		0.564		0.63		0.5971		19.0
# N12-Clean fact		0.89		0.62		0.73		13.0
# accuracy		nan		nan		0.7069		69.0
# macro avg		0.7567		0.6869		0.7102		69.0
# weighted avg		0.7236		0.7069		0.7069		69.0
#
#
#
#
# Sampling 73----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.788695652173913
#
#
# Confusion martix:  [[26.    1.    2.    0.  ]
#  [ 1.05  7.    0.95  0.  ]
#  [ 0.98  1.   15.42  2.6 ]
#  [ 2.    0.    3.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8691		0.9		0.882		29.0
# N1-Clean fact		0.78		0.78		0.78		9.0
# N2-Clean fact		0.7198		0.771		0.7436		20.0
# N12-Clean fact		0.708		0.55		0.614		11.0
# accuracy		nan		nan		0.7889		69.0
# macro avg		0.7702		0.7461		0.7562		69.0
# weighted avg		0.7873		0.7889		0.7837		69.0
#
#
#
#
# Sampling 74----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7233333333333332
#
#
# Confusion martix:  [[23.91  0.    1.09  0.  ]
#  [ 3.    3.    4.    0.  ]
#  [ 1.    0.   20.    1.  ]
#  [ 2.06  0.    6.94  3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7973		0.9564		0.8676		25.0
# N1-Clean fact		1.0		0.3		0.46		10.0
# N2-Clean fact		0.6209		0.91		0.7397		22.0
# N12-Clean fact		0.75		0.25		0.38		12.0
# accuracy		nan		nan		0.7191		69.0
# macro avg		0.79		0.5991		0.6091		69.0
# weighted avg		0.76		0.7191		0.6791		69.0
#
#
#
#
# Sampling 75----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5652173913043479
#
#
# Confusion martix:  [[20.    1.    5.    1.  ]
#  [ 4.    2.    2.    0.  ]
#  [ 3.    1.95 13.    4.05]
#  [ 4.52  0.    3.48  4.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6325		0.74		0.6848		27.0
# N1-Clean fact		0.405		0.25		0.311		8.0
# N2-Clean fact		0.5575		0.59		0.5736		22.0
# N12-Clean fact		0.438		0.33		0.379		12.0
# accuracy		nan		nan		0.57		69.0
# macro avg		0.5105		0.48		0.49		69.0
# weighted avg		0.55		0.57		0.55		69.0
#
#
#
#
# Sampling 76----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5795652173913044
#
#
# Confusion martix:  [[19.    2.    5.    2.  ]
#  [ 5.    4.    1.    1.  ]
#  [ 5.01  2.    9.99  4.  ]
#  [ 2.    0.    0.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6098		0.68		0.6399		28.0
# N1-Clean fact		0.5		0.36		0.42		11.0
# N2-Clean fact		0.6198		0.4795		0.5396		21.0
# N12-Clean fact		0.5		0.78		0.61		9.0
# accuracy		nan		nan		0.5799		69.0
# macro avg		0.5599		0.5699		0.5499		69.0
# weighted avg		0.5799		0.5799		0.5699		69.0
#
#
#
#
# Sampling 77----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6086956521739131
#
#
# Confusion martix:  [[18.65  2.93  2.42  1.  ]
#  [ 3.    6.    3.    0.  ]
#  [ 8.    0.   11.    1.  ]
#  [ 1.65  0.    4.    6.35]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5946		0.746		0.6618		25.0
# N1-Clean fact		0.6756		0.5		0.5721		12.0
# N2-Clean fact		0.5374		0.55		0.5458		20.0
# N12-Clean fact		0.7598		0.5278		0.6241		12.0
# accuracy		nan		nan		0.608		69.0
# macro avg		0.6407		0.5835		0.6033		69.0
# weighted avg		0.6209		0.608		0.6049		69.0
#
#
#
#
# Sampling 78----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6952173913043478
#
#
# Confusion martix:  [[19.89  0.    4.11  0.  ]
#  [ 2.1   4.    3.9   0.  ]
#  [ 2.1   2.   19.89  2.01]
#  [ 1.02  0.    3.79  4.19]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7923		0.8256		0.8124		24.0
# N1-Clean fact		0.67		0.4		0.5		10.0
# N2-Clean fact		0.6245		0.7656		0.6901		26.0
# N12-Clean fact		0.6766		0.4628		0.5487		9.0
# accuracy		nan		nan		0.6985		69.0
# macro avg		0.691		0.6135		0.6339		69.0
# weighted avg		0.6986		0.6985		0.6883		69.0
#
#
#
#
# Sampling 79----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6811594202898554
#
#
# Confusion martix:  [[21.  0.  6.  0.]
#  [ 1.  6.  1.  0.]
#  [ 5.  0. 14.  1.]
#  [ 1.  0.  7.  6.]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.75		0.78		0.76		27.0
# N1-Clean fact		1.0		0.75		0.86		8.0
# N2-Clean fact		0.5		0.7		0.58		20.0
# N12-Clean fact		0.86		0.43		0.57		14.0
# accuracy		nan		nan		0.68		69.0
# macro avg		0.78		0.66		0.69		69.0
# weighted avg		0.73		0.68		0.68		69.0
#
#
#
#
# Sampling 80----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7392753623188406
#
#
# Confusion martix:  [[25.    0.07  1.93  0.  ]
#  [ 2.    4.    0.    0.  ]
#  [ 4.99  0.   13.01  3.  ]
#  [ 4.    1.    1.    9.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6902		0.93		0.7902		27.0
# N1-Clean fact		0.7909		0.67		0.7258		6.0
# N2-Clean fact		0.8143		0.6205		0.7018		21.0
# N12-Clean fact		0.75		0.6		0.67		15.0
# accuracy		nan		nan		0.7401		69.0
# macro avg		0.7587		0.7001		0.7194		69.0
# weighted avg		0.7508		0.7401		0.7302		69.0
#
#
#
#
# Sampling 81----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6047826086956521
#
#
# Confusion martix:  [[18.98  1.03  0.99  1.  ]
#  [ 3.    5.    5.    0.  ]
#  [10.76  0.   10.75  0.49]
#  [ 2.    0.    3.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5446		0.8592		0.6718		22.0
# N1-Clean fact		0.8264		0.38		0.5291		13.0
# N2-Clean fact		0.5455		0.4875		0.5139		22.0
# N12-Clean fact		0.831		0.58		0.6853		12.0
# accuracy		nan		nan		0.6036		69.0
# macro avg		0.6869		0.5773		0.5983		69.0
# weighted avg		0.6483		0.6036		0.5945		69.0
#
#
#
#
# Sampling 82----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6057971014492755
#
#
# Confusion martix:  [[24.8  3.   4.2  0. ]
#  [ 2.   3.   2.   0. ]
#  [ 9.   1.  12.   3. ]
#  [ 1.   0.   2.   2. ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6769		0.774		0.7191		32.0
# N1-Clean fact		0.43		0.43		0.43		7.0
# N2-Clean fact		0.594		0.48		0.5291		25.0
# N12-Clean fact		0.4		0.4		0.4		5.0
# accuracy		nan		nan		0.6049		69.0
# macro avg		0.528		0.518		0.518		69.0
# weighted avg		0.5991		0.6049		0.598		69.0
#
#
#
#
# Sampling 83----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6685507246376814
#
#
# Confusion martix:  [[17.05  1.    5.95  1.  ]
#  [ 3.    5.    2.    1.  ]
#  [ 3.92  0.   15.08  0.  ]
#  [ 3.    0.    2.    9.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6321		0.682		0.6531		25.0
# N1-Clean fact		0.83		0.45		0.59		11.0
# N2-Clean fact		0.6026		0.794		0.6834		19.0
# N12-Clean fact		0.82		0.64		0.72		14.0
# accuracy		nan		nan		0.6713		69.0
# macro avg		0.7213		0.6413		0.6613		69.0
# weighted avg		0.6921		0.6713		0.6626		69.0
#
#
#
#
# Sampling 84----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7824637681159419
#
#
# Confusion martix:  [[20.03  0.    6.97  1.  ]
#  [ 0.    8.    0.    0.  ]
#  [ 1.04  0.   15.96  1.  ]
#  [ 0.    0.    5.   10.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.9484		0.7112		0.8198		28.0
# N1-Clean fact		1.0		1.0		1.0		8.0
# N2-Clean fact		0.5702		0.8876		0.6991		18.0
# N12-Clean fact		0.83		0.67		0.74		15.0
# accuracy		nan		nan		0.7802		69.0
# macro avg		0.8395		0.8195		0.8099		69.0
# weighted avg		0.8295		0.7802		0.7899		69.0
#
#
#
#
# Sampling 85----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7663768115942028
#
#
# Confusion martix:  [[21.    0.    1.    0.  ]
#  [ 4.    3.    1.    0.  ]
#  [ 3.94  0.   20.06  3.  ]
#  [ 2.15  0.    1.03  8.82]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6782		0.95		0.7897		22.0
# N1-Clean fact		1.0		0.38		0.55		8.0
# N2-Clean fact		0.8694		0.7424		0.8006		27.0
# N12-Clean fact		0.7464		0.7356		0.741		12.0
# accuracy		nan		nan		0.767		69.0
# macro avg		0.8188		0.7046		0.717		69.0
# weighted avg		0.7985		0.767		0.7585		69.0
#
#
#
#
# Sampling 86----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6956521739130435
#
#
# Confusion martix:  [[18.    1.    5.    0.  ]
#  [ 1.15  6.    3.85  0.  ]
#  [ 4.    1.   17.    2.  ]
#  [ 0.    0.    3.    7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7755		0.75		0.767		24.0
# N1-Clean fact		0.75		0.55		0.63		11.0
# N2-Clean fact		0.593		0.71		0.6415		24.0
# N12-Clean fact		0.78		0.7		0.74		10.0
# accuracy		nan		nan		0.7		69.0
# macro avg		0.72		0.68		0.69		69.0
# weighted avg		0.7085		0.7		0.7		69.0
#
#
#
#
# Sampling 87----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7310144927536232
#
#
# Confusion martix:  [[27.32  0.    1.68  0.  ]
#  [ 3.04  2.    2.96  0.  ]
#  [ 2.    0.   15.    2.  ]
#  [ 1.84  0.96  4.08  6.12]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7997		0.9428		0.8636		29.0
# N1-Clean fact		0.6832		0.25		0.3616		8.0
# N2-Clean fact		0.6322		0.79		0.7006		19.0
# N12-Clean fact		0.753		0.4696		0.5778		13.0
# accuracy		nan		nan		0.7282		69.0
# macro avg		0.7175		0.6156		0.626		69.0
# weighted avg		0.7312		0.7282		0.7067		69.0
#
#
#
#
# Sampling 88----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.782608695652174
#
#
# Confusion martix:  [[22.    0.    1.    1.  ]
#  [ 4.    6.    0.    0.  ]
#  [ 3.97  0.   17.    2.03]
#  [ 2.    0.    1.    9.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6906		0.92		0.7903		24.0
# N1-Clean fact		1.0		0.6		0.75		10.0
# N2-Clean fact		0.89		0.74		0.81		23.0
# N12-Clean fact		0.7482		0.75		0.7491		12.0
# accuracy		nan		nan		0.78		69.0
# macro avg		0.8297		0.75		0.77		69.0
# weighted avg		0.81		0.78		0.78		69.0
#
#
#
#
# Sampling 89----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7215942028985506
#
#
# Confusion martix:  [[21.79  2.    0.21  1.  ]
#  [ 0.    6.    0.    0.  ]
#  [ 5.    0.   19.    1.  ]
#  [ 6.    0.    4.    3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6679		0.8716		0.7558		25.0
# N1-Clean fact		0.75		1.0		0.86		6.0
# N2-Clean fact		0.8216		0.76		0.7879		25.0
# N12-Clean fact		0.6		0.23		0.33		13.0
# accuracy		nan		nan		0.7179		69.0
# macro avg		0.7079		0.7179		0.6879		69.0
# weighted avg		0.7158		0.7179		0.6979		69.0
#
#
#
#
# Sampling 90----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7465217391304347
#
#
# Confusion martix:  [[23.    0.    1.    0.  ]
#  [ 2.02  6.    3.98  0.  ]
#  [ 5.    0.   12.    1.  ]
#  [ 2.34  0.    2.15 10.51]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7128		0.96		0.8163		24.0
# N1-Clean fact		1.0		0.5		0.67		12.0
# N2-Clean fact		0.6262		0.67		0.6474		18.0
# N12-Clean fact		0.9151		0.7006		0.7904		15.0
# accuracy		nan		nan		0.7451		69.0
# macro avg		0.8151		0.7051		0.7302		69.0
# weighted avg		0.7851		0.7451		0.7402		69.0
#
#
#
#
# Sampling 91----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7681159420289855
#
#
# Confusion martix:  [[24.    1.    5.    0.  ]
#  [ 1.    9.    1.    0.  ]
#  [ 2.    0.   12.    0.  ]
#  [ 1.76  0.    4.24  8.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.8372		0.8		0.8148		30.0
# N1-Clean fact		0.9		0.82		0.86		11.0
# N2-Clean fact		0.5428		0.86		0.6652		14.0
# N12-Clean fact		1.0		0.57		0.73		14.0
# accuracy		nan		nan		0.77		69.0
# macro avg		0.82		0.76		0.77		69.0
# weighted avg		0.82		0.77		0.7724		69.0
#
#
#
#
# Sampling 92----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.721159420289855
#
#
# Confusion martix:  [[20.    2.02  4.98  0.  ]
#  [ 3.    3.    2.    0.  ]
#  [ 2.    0.   19.76  1.24]
#  [ 0.16  0.    3.84  7.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7952		0.74		0.7668		27.0
# N1-Clean fact		0.598		0.38		0.4594		8.0
# N2-Clean fact		0.65		0.8592		0.7359		23.0
# N12-Clean fact		0.8584		0.64		0.7316		11.0
# accuracy		nan		nan		0.7176		69.0
# macro avg		0.7236		0.6564		0.6762		69.0
# weighted avg		0.7335		0.7176		0.7164		69.0
#
#
#
#
# Sampling 93----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6708695652173915
#
#
# Confusion martix:  [[21.    1.    1.    0.  ]
#  [ 7.    4.    2.    0.  ]
#  [ 6.23  0.   15.29  0.48]
#  [ 2.    0.    3.    6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5777		0.91		0.7077		23.0
# N1-Clean fact		0.8		0.31		0.44		13.0
# N2-Clean fact		0.7158		0.6945		0.7087		22.0
# N12-Clean fact		0.9328		0.55		0.6908		11.0
# accuracy		nan		nan		0.6729		69.0
# macro avg		0.7585		0.6129		0.6381		69.0
# weighted avg		0.7233		0.6729		0.6558		69.0
#
#
#
#
# Sampling 94----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6784057971014497
#
#
# Confusion martix:  [[23.    1.    1.95  2.05]
#  [ 3.    4.    4.    0.  ]
#  [ 5.9   1.01 11.99  1.1 ]
#  [ 1.03  0.    1.15  7.82]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7014		0.82		0.7517		28.0
# N1-Clean fact		0.669		0.36		0.4697		11.0
# N2-Clean fact		0.6286		0.5995		0.616		20.0
# N12-Clean fact		0.7143		0.782		0.7445		10.0
# accuracy		nan		nan		0.6794		69.0
# macro avg		0.6777		0.6431		0.6455		69.0
# weighted avg		0.6751		0.6794		0.6681		69.0
#
#
#
#
# Sampling 95----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6939130434782609
#
#
# Confusion martix:  [[20.56  1.    5.44  0.  ]
#  [ 1.15  8.    2.85  0.  ]
#  [ 2.14  0.   14.29  1.57]
#  [ 2.    0.    4.97  5.03]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7969		0.7624		0.7769		27.0
# N1-Clean fact		0.89		0.67		0.76		12.0
# N2-Clean fact		0.5206		0.7941		0.627		18.0
# N12-Clean fact		0.7639		0.4224		0.545		12.0
# accuracy		nan		nan		0.6962		69.0
# macro avg		0.7427		0.6591		0.6787		69.0
# weighted avg		0.7352		0.6962		0.6958		69.0
#
#
#
#
# Sampling 96----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6223188405797102
#
#
# Confusion martix:  [[20.    2.    3.    2.  ]
#  [ 2.    6.    2.    0.  ]
#  [ 3.56  2.   12.94  2.5 ]
#  [ 1.    0.    6.    4.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7532		0.74		0.7444		27.0
# N1-Clean fact		0.6		0.6		0.6		10.0
# N2-Clean fact		0.5388		0.617		0.5782		21.0
# N12-Clean fact		0.47		0.36		0.41		11.0
# accuracy		nan		nan		0.6194		69.0
# macro avg		0.594		0.5794		0.5794		69.0
# weighted avg		0.619		0.6194		0.619		69.0
#
#
#
#
# Sampling 97----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.6956521739130435
#
#
# Confusion martix:  [[21.    4.    3.    1.  ]
#  [ 2.    5.    2.    0.  ]
#  [ 4.    0.   16.    0.  ]
#  [ 1.65  0.    3.35  6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7305		0.72		0.727		29.0
# N1-Clean fact		0.56		0.56		0.56		9.0
# N2-Clean fact		0.6595		0.8		0.723		20.0
# N12-Clean fact		0.86		0.55		0.67		11.0
# accuracy		nan		nan		0.7		69.0
# macro avg		0.7		0.66		0.67		69.0
# weighted avg		0.71		0.7		0.69		69.0
#
#
#
#
# Sampling 98----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.5895652173913044
#
#
# Confusion martix:  [[20.    0.26  2.74  1.  ]
#  [ 4.1   4.    1.9   1.  ]
#  [ 4.18  1.   14.68  2.14]
#  [ 5.89  0.    4.11  2.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.5866		0.83		0.6888		24.0
# N1-Clean fact		0.7662		0.36		0.4922		11.0
# N2-Clean fact		0.628		0.6706		0.646		22.0
# N12-Clean fact		0.3244		0.17		0.2186		12.0
# accuracy		nan		nan		0.5902		69.0
# macro avg		0.5757		0.5068		0.5142		69.0
# weighted avg		0.5841		0.5902		0.5604		69.0
#
#
#
#
# Sampling 99----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.693768115942029
#
#
# Confusion martix:  [[25.    0.    1.    0.  ]
#  [ 1.    2.    1.    0.  ]
#  [ 8.13  0.   14.87  0.  ]
#  [ 5.44  0.    4.56  6.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.6316		0.96		0.7643		26.0
# N1-Clean fact		1.0		0.5		0.67		4.0
# N2-Clean fact		0.6939		0.6448		0.6697		23.0
# N12-Clean fact		1.0		0.38		0.55		16.0
# accuracy		nan		nan		0.6974		69.0
# macro avg		0.8314		0.6187		0.6587		69.0
# weighted avg		0.7606		0.6974		0.6774		69.0
#
#
#
#
# Sampling 100----------------------------------------------------------------------------------
#
# Acc_train_ave:  1.0
# Acc_test_ave:  0.7217391304347827
#
#
# Confusion martix:  [[25.4   0.    2.    0.6 ]
#  [ 2.    3.    2.    0.  ]
#  [ 3.99  1.   18.4   0.61]
#  [ 4.    0.    3.    3.  ]]
#
#
# Classes		precision		recall		f1-score		support
# Clean fact		0.7148		0.906		0.7998		28.0
# N1-Clean fact		0.75		0.43		0.55		7.0
# N2-Clean fact		0.724		0.766		0.7422		24.0
# N12-Clean fact		0.7375		0.3		0.4237		10.0
# accuracy		nan		nan		0.7203		69.0
# macro avg		0.7342		0.598		0.6285		69.0
# weighted avg		0.7262		0.7203		0.7003		69.0

# %%
final_ave_ConfusionMatrix=(np.round(np.average(conf_martix_ave_collect,axis=0))).astype(int)
print("Confusion Matrix\n",final_ave_ConfusionMatrix)
# Out:
# Confusion Matrix
#  [[22  1  3  1]
#  [ 2  5  2  0]
#  [ 4  1 15  1]
#  [ 2  0  3  6]]

# %%
class_names = ['0', '1', '2', '3']
fig, ax = plot_confusion_matrix(conf_mat=final_ave_ConfusionMatrix,
                                colorbar=True,
                                #show_absolute=False,
                                #show_normed=True,
                                class_names=class_names)
plt.show()

# %%
final_ave_ReportMatrix=np.round (np.average(report_matrix_ave_collect,axis=0),decimals=3)
print("Report Matrix\n",final_ave_ReportMatrix)
# Out:
# Report Matrix
#  [[ 0.724  0.838  0.772 26.73 ]
#  [ 0.744  0.536  0.597  9.02 ]
#  [ 0.667  0.717  0.683 21.39 ]
#  [ 0.763  0.543  0.617 11.86 ]
#  [   nan    nan  0.704 69.   ]
#  [ 0.724  0.658  0.667 69.   ]
#  [ 0.725  0.704  0.696 69.   ]]

# %% [markdown]
# ## 4.3 Improt preprocessed results (importance)

# %%
path_preprocessed_results="./RF_results/preprocessed_results_sl3_2M_4L_Cross.csv"
preprocessed_results=np.array(pd.read_csv(path_preprocessed_results,header=None))
preprocessed_results.shape
# Out:
# (100, 10304)

# %% [markdown]
# ## 4.4 Compute the important features for each undersampling

# %%
groups=4
top_select=120

# %%
print("preprocessed_results.shape[0]",preprocessed_results.shape,"\n")

group_importance=[]
selected_feature_indices=[]

memebers=int(preprocessed_results.shape[0]/float(groups))
for group_i in np.arange(groups):
    group_importance_i=np.sum(preprocessed_results[group_i*memebers:(group_i+1)*memebers,:],axis=0)
    indices_i=np.argsort(group_importance_i)[::-1][0:top_select]
    
    group_importance.append(group_importance_i)
    selected_feature_indices.append(indices_i)
# Out:
# preprocessed_results.shape[0] (100, 10304)

# %%
for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.draw_with_importance(group_importance[group_i],original_edge_width,original_edge_length,top_select)
# Out:
# The number of group 0
# ./Defined/Functions.py:107: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(p_pad,p_w_pad, p_h_pad)
# The number of group 1
# The number of group 2
# The number of group 3

# %%
F.draw_with_importance(np.mean(group_importance,axis=0),original_edge_width,original_edge_length,top_select)

# %% [markdown]
# ## 4.5 Compute the common important features from each undersampling

# %%
interect_indices=F.intersect_2Dlist(selected_feature_indices)
background=np.zeros(original_edge_length*original_edge_width)
background[F.intersect_2Dlist(selected_feature_indices)]=group_importance[0][interect_indices]

# %%
common_feature_catch=[]
for interect_indices_i in interect_indices:
    common_feature_catch.append([int(interect_indices_i/(original_edge_length)),interect_indices_i%(original_edge_length)])

for group_i in np.arange(groups):
    print("The number of group",group_i)
    F.show_one_figure_with_keyfeature(group_importance[group_i],common_feature_catch,original_edge_width,original_edge_length)
    
F.show_one_figure_with_keyfeature(np.average(np.array(group_importance),axis=0),common_feature_catch,original_edge_width,original_edge_length)
# Out:
# The number of group 0
# The number of group 1
# The number of group 2
# The number of group 3

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length))
plt.axis('off')
plt.show()

# %%
plt.imshow(background.reshape(original_edge_width,original_edge_length),plt.cm.gray)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4.6 Show the common important features from each undersampling and comparing with the original key features

# %%
F.show_one_figure_with_keyfeature(Collect_noise_data.sum(axis=0),common_feature_catch,original_edge_width,original_edge_length)

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()

# %%
plt.imshow(Collect_noise_data.sum(axis=0),plt.cm.gray)
plt.axis('off')
plt.show()
